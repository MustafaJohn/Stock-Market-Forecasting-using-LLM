# %%
import pandas as pd  
import numpy as np
import torch
from chronos import BaseChronosPipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tqdm as notebook_tqdm

# %%
# Using GPU if available
device_map = "cpu"
device = torch.device("cpu")

# %%
# Load Chronos model
pipeline = BaseChronosPipeline.from_pretrained(
    "amazon/chronos-bolt-small",  # or "chronos-t5-small"
    device_map=device,
    torch_dtype=torch.float32
)

# %%
# Constants
ID_COL = "PERMNO"
TARGET_COL = "ExcessReturn"
DATE_COL = "DlyCalDt"
WINDOW = 5  # days of context

# Load data
in_sample_df = pd.read_csv("../Cleaned Datasets/in_sample_cleaned.csv")
out_sample_df = pd.read_csv("../Cleaned Datasets/out_sample_cleaned.csv")

# %%
in_sample_df = in_sample_df[['PERMNO', 'DlyCalDt', 'ExcessReturn']]
out_sample_df = out_sample_df[['PERMNO', 'DlyCalDt', 'ExcessReturn']]

print(in_sample_df.info())
print(out_sample_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199550 entries, 0 to 199549
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   PERMNO        199550 non-null  int64
#  1   DlyCalDt      199550 non-null  object
#  2   ExcessReturn  199550 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112400 entries, 0 to 112399
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   PERMNO        112400 non-null  int64
#  1   DlyCalDt      112400 non-null  object
#  2   ExcessReturn  112400 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.6+ MB
# None

# %%
# Create rolling window for predictors for Bolt models

combined_df = pd.concat([in_sample_df, out_sample_df])
combined_df = combined_df.sort_values([ID_COL, DATE_COL]).reset_index(drop=True)
combined_df[DATE_COL] = pd.to_datetime(combined_df[DATE_COL])

contexts = []
targets = []
records = []

for id, grp in combined_df.groupby(ID_COL):
    values = grp[TARGET_COL].values
    dates = grp[DATE_COL].values

    for i in range(len(values) - WINDOW):
        pred_date = dates[i + WINDOW]
        if pred_date >= pd.to_datetime("2016-01-01"):
            contexts.append(torch.tensor(values[i:i+WINDOW], dtype=torch.float32, device=device))
            targets.append(values[i+WINDOW])
            records.append({
                ID_COL: id,
                TARGET_COL: values[i+WINDOW],
                DATE_COL: pred_date
            })

# %%
contexts
# Out:
# [tensor([-0.0041,  0.0037,  0.0052, -0.0138, -0.0083]),
#  tensor([ 0.0037,  0.0052, -0.0138, -0.0083, -0.0182]),
#  tensor([ 0.0052, -0.0138, -0.0083, -0.0182,  0.0041]),
#  tensor([-0.0138, -0.0083, -0.0182,  0.0041, -0.0224]),
#  tensor([-0.0083, -0.0182,  0.0041, -0.0224, -0.0267]),
#  tensor([-0.0182,  0.0041, -0.0224, -0.0267, -0.0254]),
#  tensor([ 0.0041, -0.0224, -0.0267, -0.0254, -0.0054]),
#  tensor([-0.0224, -0.0267, -0.0254, -0.0054,  0.0261]),
#  tensor([-0.0267, -0.0254, -0.0054,  0.0261, -0.0276]),
#  tensor([-0.0254, -0.0054,  0.0261, -0.0276,  0.0109]),
#  tensor([-0.0054,  0.0261, -0.0276,  0.0109, -0.0096]),
#  tensor([ 0.0261, -0.0276,  0.0109, -0.0096,  0.0094]),
#  tensor([-0.0276,  0.0109, -0.0096,  0.0094, -0.0072]),
#  tensor([ 0.0109, -0.0096,  0.0094, -0.0072,  0.0072]),
#  tensor([-0.0096,  0.0094, -0.0072,  0.0072,  0.0285]),
#  tensor([ 0.0094, -0.0072,  0.0072,  0.0285, -0.0300]),
#  tensor([-0.0072,  0.0072,  0.0285, -0.0300,  0.0189]),
#  tensor([ 0.0072,  0.0285, -0.0300,  0.0189, -0.0063]),
#  tensor([ 0.0285, -0.0300,  0.0189, -0.0063,  0.0331]),
#  tensor([-0.0300,  0.0189, -0.0063,  0.0331,  0.0370]),
#  tensor([ 0.0189, -0.0063,  0.0331,  0.0370, -0.0111]),
#  tensor([-0.0063,  0.0331,  0.0370, -0.0111, -0.0301]),
#  tensor([ 0.0331,  0.0370, -0.0111, -0.0301,  0.0087]),
#  tensor([ 0.0370, -0.0111, -0.0301,  0.0087,  0.0166]),
#  tensor([-0.0111, -0.0301,  0.0087,  0.0166, -0.0163]),
#  tensor([-0.0301,  0.0087,  0.0166, -0.0163, -0.0389]),
#  tensor([ 0.0087,  0.0166, -0.0163, -0.0389,  0.0079]),
#  tensor([ 0.0166, -0.0163, -0.0389,  0.0079,  0.0015]),
#  tensor([-0.0163, -0.0389,  0.0079,  0.0015, -0.0167]),
#  tensor([-0.0389,  0.0079,  0.0015, -0.0167,  0.0316]),
#  tensor([ 0.0079,  0.0015, -0.0167,  0.0316,  0.0136]),
#  tensor([ 0.0015, -0.0167,  0.0316,  0.0136,  0.0261]),
#  tensor([-0.0167,  0.0316,  0.0136,  0.0261, -0.0118]),
#  tensor([ 0.0316,  0.0136,  0.0261, -0.0118, -0.0082]),
#  tensor([ 0.0136,  0.0261, -0.0118, -0.0082,  0.0149]),
#  tensor([ 0.0261, -0.0118, -0.0082,  0.0149, -0.0185]),
#  tensor([-0.0118, -0.0082,  0.0149, -0.0185,  0.0052]),
#  tensor([-0.0082,  0.0149, -0.0185,  0.0052,  0.0099]),
#  tensor([ 0.0149, -0.0185,  0.0052,  0.0099,  0.0011]),
#  tensor([-0.0185,  0.0052,  0.0099,  0.0011, -0.0088]),
#  tensor([ 0.0052,  0.0099,  0.0011, -0.0088,  0.0331]),
#  tensor([ 0.0099,  0.0011, -0.0088,  0.0331,  0.0038]),
#  tensor([ 0.0011, -0.0088,  0.0331,  0.0038,  0.0093]),
#  tensor([-0.0088,  0.0331,  0.0038,  0.0093,  0.0061]),
#  tensor([ 0.0331,  0.0038,  0.0093,  0.0061, -0.0030]),
#  tensor([ 0.0038,  0.0093,  0.0061, -0.0030, -0.0081]),
#  tensor([ 0.0093,  0.0061, -0.0030, -0.0081, -0.0063]),
#  tensor([ 0.0061, -0.0030, -0.0081, -0.0063, -0.0029]),
#  tensor([-0.0030, -0.0081, -0.0063, -0.0029,  0.0185]),
#  tensor([-0.0081, -0.0063, -0.0029,  0.0185, -0.0058]),
#  tensor([-0.0063, -0.0029,  0.0185, -0.0058, -0.0149]),
#  tensor([-0.0029,  0.0185, -0.0058, -0.0149,  0.0102]),
#  tensor([ 0.0185, -0.0058, -0.0149,  0.0102,  0.0265]),
#  tensor([-0.0058, -0.0149,  0.0102,  0.0265,  0.0045]),
#  tensor([-0.0149,  0.0102,  0.0265,  0.0045, -0.0025]),
#  tensor([ 0.0102,  0.0265,  0.0045, -0.0025, -0.0037]),
#  tensor([ 0.0265,  0.0045, -0.0025, -0.0037,  0.0001]),
#  tensor([ 0.0045, -0.0025, -0.0037,  0.0001, -0.0081]),
#  tensor([-0.0025, -0.0037,  0.0001, -0.0081,  0.0040]),
#  tensor([-0.0037,  0.0001, -0.0081,  0.0040,  0.0151]),
#  tensor([ 1.2818e-04, -8.0799e-03,  3.9908e-03,  1.5103e-02, -5.7675e-06]),
#  tensor([-8.0799e-03,  3.9908e-03,  1.5103e-02, -5.7675e-06, -5.9608e-03]),
#  tensor([ 3.9908e-03,  1.5103e-02, -5.7675e-06, -5.9608e-03,  6.6629e-03]),
#  tensor([ 1.5103e-02, -5.7675e-06, -5.9608e-03,  6.6629e-03, -1.2448e-02]),
#  tensor([-5.7675e-06, -5.9608e-03,  6.6629e-03, -1.2448e-02, -9.4542e-03]),
#  tensor([-0.0060,  0.0067, -0.0124, -0.0095,  0.0140]),
#  tensor([ 0.0067, -0.0124, -0.0095,  0.0140, -0.0255]),
#  tensor([-0.0124, -0.0095,  0.0140, -0.0255,  0.0045]),
#  tensor([-0.0095,  0.0140, -0.0255,  0.0045,  0.0054]),
#  tensor([ 0.0140, -0.0255,  0.0045,  0.0054,  0.0256]),
#  tensor([-0.0255,  0.0045,  0.0054,  0.0256,  0.0332]),
#  tensor([0.0045, 0.0054, 0.0256, 0.0332, 0.0014]),
#  tensor([ 0.0054,  0.0256,  0.0332,  0.0014, -0.0011]),
#  tensor([ 0.0256,  0.0332,  0.0014, -0.0011,  0.0009]),
#  tensor([ 0.0332,  0.0014, -0.0011,  0.0009,  0.0146]),
#  tensor([ 0.0014, -0.0011,  0.0009,  0.0146,  0.0080]),
#  tensor([-0.0011,  0.0009,  0.0146,  0.0080, -0.0091]),
#  tensor([ 0.0009,  0.0146,  0.0080, -0.0091, -0.0007]),
#  tensor([ 0.0146,  0.0080, -0.0091, -0.0007, -0.0079]),
#  tensor([ 0.0080, -0.0091, -0.0007, -0.0079,  0.0071]),
#  tensor([-0.0091, -0.0007, -0.0079,  0.0071, -0.0008]),
#  tensor([-0.0007, -0.0079,  0.0071, -0.0008, -0.0218]),
#  tensor([-0.0079,  0.0071, -0.0008, -0.0218, -0.0063]),
#  tensor([ 0.0071, -0.0008, -0.0218, -0.0063,  0.0053]),
#  tensor([-0.0008, -0.0218, -0.0063,  0.0053, -0.0100]),
#  tensor([-0.0218, -0.0063,  0.0053, -0.0100, -0.0085]),
#  tensor([-0.0063,  0.0053, -0.0100, -0.0085,  0.0007]),
#  tensor([ 0.0053, -0.0100, -0.0085,  0.0007,  0.0101]),
#  tensor([-0.0100, -0.0085,  0.0007,  0.0101, -0.0007]),
#  tensor([-0.0085,  0.0007,  0.0101, -0.0007,  0.0109]),
#  tensor([ 0.0007,  0.0101, -0.0007,  0.0109, -0.0067]),
#  tensor([ 0.0101, -0.0007,  0.0109, -0.0067,  0.0034]),
#  tensor([-0.0007,  0.0109, -0.0067,  0.0034, -0.0196]),
#  tensor([ 0.0109, -0.0067,  0.0034, -0.0196,  0.0082]),
#  tensor([-0.0067,  0.0034, -0.0196,  0.0082, -0.0088]),
#  tensor([ 0.0034, -0.0196,  0.0082, -0.0088,  0.0047]),
#  tensor([-0.0196,  0.0082, -0.0088,  0.0047, -0.0093]),
#  tensor([ 0.0082, -0.0088,  0.0047, -0.0093,  0.0155]),
#  tensor([-0.0088,  0.0047, -0.0093,  0.0155, -0.0050]),
#  tensor([ 0.0047, -0.0093,  0.0155, -0.0050,  0.0276]),
#  tensor([-0.0093,  0.0155, -0.0050,  0.0276,  0.0103]),
#  tensor([ 0.0155, -0.0050,  0.0276,  0.0103, -0.0091]),
#  tensor([-0.0050,  0.0276,  0.0103, -0.0091,  0.0061]),
#  tensor([ 0.0276,  0.0103, -0.0091,  0.0061, -0.0009]),
#  tensor([ 0.0103, -0.0091,  0.0061, -0.0009, -0.0005]),
#  tensor([-0.0091,  0.0061, -0.0009, -0.0005, -0.0010]),
#  tensor([ 0.0061, -0.0009, -0.0005, -0.0010, -0.0125]),
#  tensor([-0.0009, -0.0005, -0.0010, -0.0125,  0.0057]),
#  tensor([-0.0005, -0.0010, -0.0125,  0.0057, -0.0123]),
#  tensor([-0.0010, -0.0125,  0.0057, -0.0123, -0.0052]),
#  tensor([-0.0125,  0.0057, -0.0123, -0.0052, -0.0095]),
#  tensor([ 0.0057, -0.0123, -0.0052, -0.0095, -0.0207]),
#  tensor([-0.0123, -0.0052, -0.0095, -0.0207, -0.0078]),
#  tensor([-0.0052, -0.0095, -0.0207, -0.0078, -0.0081]),
#  tensor([-0.0095, -0.0207, -0.0078, -0.0081,  0.0059]),
#  tensor([-0.0207, -0.0078, -0.0081,  0.0059, -0.0045]),
#  tensor([-0.0078, -0.0081,  0.0059, -0.0045,  0.0018]),
#  tensor([-0.0081,  0.0059, -0.0045,  0.0018,  0.0118]),
#  tensor([ 0.0059, -0.0045,  0.0018,  0.0118, -0.0050]),
#  tensor([-0.0045,  0.0018,  0.0118, -0.0050,  0.0021]),
#  tensor([ 0.0018,  0.0118, -0.0050,  0.0021,  0.0211]),
#  tensor([ 0.0118, -0.0050,  0.0021,  0.0211, -0.0533]),
#  tensor([-0.0050,  0.0021,  0.0211, -0.0533, -0.0285]),
#  tensor([ 0.0021,  0.0211, -0.0533, -0.0285,  0.0260]),
#  tensor([ 0.0211, -0.0533, -0.0285,  0.0260,  0.0282]),
#  tensor([-0.0533, -0.0285,  0.0260,  0.0282,  0.0228]),
#  tensor([-0.0285,  0.0260,  0.0282,  0.0228, -0.0086]),
#  tensor([ 0.0260,  0.0282,  0.0228, -0.0086, -0.0137]),
#  tensor([ 0.0282,  0.0228, -0.0086, -0.0137,  0.0085]),
#  tensor([ 0.0228, -0.0086, -0.0137,  0.0085, -0.0052]),
#  tensor([-0.0086, -0.0137,  0.0085, -0.0052,  0.0230]),
#  tensor([-0.0137,  0.0085, -0.0052,  0.0230,  0.0014]),
#  tensor([ 0.0085, -0.0052,  0.0230,  0.0014,  0.0154]),
#  tensor([-0.0052,  0.0230,  0.0014,  0.0154, -0.0078]),
#  tensor([ 0.0230,  0.0014,  0.0154, -0.0078,  0.0032]),
#  tensor([ 0.0014,  0.0154, -0.0078,  0.0032,  0.0070]),
#  tensor([ 0.0154, -0.0078,  0.0032,  0.0070, -0.0008]),
#  tensor([-0.0078,  0.0032,  0.0070, -0.0008, -0.0068]),
#  tensor([ 0.0032,  0.0070, -0.0008, -0.0068, -0.0001]),
#  tensor([ 0.0070, -0.0008, -0.0068, -0.0001, -0.0026]),
#  tensor([-0.0008, -0.0068, -0.0001, -0.0026,  0.0032]),
#  tensor([-0.0068, -0.0001, -0.0026,  0.0032, -0.0058]),
#  tensor([-0.0001, -0.0026,  0.0032, -0.0058, -0.0426]),
#  tensor([-0.0026,  0.0032, -0.0058, -0.0426,  0.0018]),
#  tensor([ 0.0032, -0.0058, -0.0426,  0.0018, -0.0034]),
#  tensor([-0.0058, -0.0426,  0.0018, -0.0034,  0.0035]),
#  tensor([-0.0426,  0.0018, -0.0034,  0.0035, -0.0120]),
#  tensor([ 0.0018, -0.0034,  0.0035, -0.0120, -0.0120]),
#  tensor([-0.0034,  0.0035, -0.0120, -0.0120,  0.0014]),
#  tensor([ 0.0035, -0.0120, -0.0120,  0.0014, -0.0007]),
#  tensor([-0.0120, -0.0120,  0.0014, -0.0007,  0.0114]),
#  tensor([-0.0120,  0.0014, -0.0007,  0.0114, -0.0023]),
#  tensor([ 0.0014, -0.0007,  0.0114, -0.0023, -0.0128]),
#  tensor([-0.0007,  0.0114, -0.0023, -0.0128, -0.0002]),
#  tensor([ 0.0114, -0.0023, -0.0128, -0.0002,  0.0033]),
#  tensor([-0.0023, -0.0128, -0.0002,  0.0033, -0.0041]),
#  tensor([-0.0128, -0.0002,  0.0033, -0.0041, -0.0013]),
#  tensor([-1.5338e-04,  3.3349e-03, -4.0658e-03, -1.3179e-03, -8.5930e-06]),
#  tensor([ 3.3349e-03, -4.0658e-03, -1.3179e-03, -8.5930e-06,  5.3810e-03]),
#  tensor([-4.0658e-03, -1.3179e-03, -8.5930e-06,  5.3810e-03,  1.5848e-03]),
#  tensor([-1.3179e-03, -8.5930e-06,  5.3810e-03,  1.5848e-03, -2.0343e-03]),
#  tensor([-8.5930e-06,  5.3810e-03,  1.5848e-03, -2.0343e-03,  1.0061e-03]),
#  tensor([ 0.0054,  0.0016, -0.0020,  0.0010,  0.0071]),
#  tensor([ 0.0016, -0.0020,  0.0010,  0.0071, -0.0082]),
#  tensor([-0.0020,  0.0010,  0.0071, -0.0082, -0.0038]),
#  tensor([ 0.0010,  0.0071, -0.0082, -0.0038,  0.0025]),
#  tensor([ 0.0071, -0.0082, -0.0038,  0.0025,  0.0010]),
#  tensor([-0.0082, -0.0038,  0.0025,  0.0010,  0.0138]),
#  tensor([-0.0038,  0.0025,  0.0010,  0.0138, -0.0052]),
#  tensor([ 0.0025,  0.0010,  0.0138, -0.0052, -0.0114]),
#  tensor([ 0.0010,  0.0138, -0.0052, -0.0114,  0.0076]),
#  tensor([ 0.0138, -0.0052, -0.0114,  0.0076, -0.0028]),
#  tensor([-0.0052, -0.0114,  0.0076, -0.0028,  0.0038]),
#  tensor([-0.0114,  0.0076, -0.0028,  0.0038, -0.0072]),
#  tensor([ 0.0076, -0.0028,  0.0038, -0.0072, -0.0198]),
#  tensor([-0.0028,  0.0038, -0.0072, -0.0198,  0.0166]),
#  tensor([ 0.0038, -0.0072, -0.0198,  0.0166, -0.0105]),
#  tensor([-0.0072, -0.0198,  0.0166, -0.0105, -0.0052]),
#  tensor([-0.0198,  0.0166, -0.0105, -0.0052,  0.0121]),
#  tensor([ 0.0166, -0.0105, -0.0052,  0.0121, -0.0115]),
#  tensor([-0.0105, -0.0052,  0.0121, -0.0115, -0.0057]),
#  tensor([-0.0052,  0.0121, -0.0115, -0.0057, -0.0002]),
#  tensor([ 0.0121, -0.0115, -0.0057, -0.0002,  0.0030]),
#  tensor([-0.0115, -0.0057, -0.0002,  0.0030, -0.0002]),
#  tensor([-0.0057, -0.0002,  0.0030, -0.0002, -0.0135]),
#  tensor([-0.0002,  0.0030, -0.0002, -0.0135, -0.0109]),
#  tensor([ 0.0030, -0.0002, -0.0135, -0.0109,  0.0055]),
#  tensor([-0.0002, -0.0135, -0.0109,  0.0055,  0.0120]),
#  tensor([-0.0135, -0.0109,  0.0055,  0.0120, -0.0122]),
#  tensor([-0.0109,  0.0055,  0.0120, -0.0122,  0.0146]),
#  tensor([ 0.0055,  0.0120, -0.0122,  0.0146, -0.0008]),
#  tensor([ 0.0120, -0.0122,  0.0146, -0.0008,  0.0015]),
#  tensor([-0.0122,  0.0146, -0.0008,  0.0015,  0.0155]),
#  tensor([ 0.0146, -0.0008,  0.0015,  0.0155, -0.0036]),
#  tensor([-0.0008,  0.0015,  0.0155, -0.0036, -0.0113]),
#  tensor([ 0.0015,  0.0155, -0.0036, -0.0113, -0.0126]),
#  tensor([ 0.0155, -0.0036, -0.0113, -0.0126,  0.0032]),
#  tensor([-0.0036, -0.0113, -0.0126,  0.0032, -0.0074]),
#  tensor([-0.0113, -0.0126,  0.0032, -0.0074,  0.0035]),
#  tensor([-0.0126,  0.0032, -0.0074,  0.0035, -0.0129]),
#  tensor([ 0.0032, -0.0074,  0.0035, -0.0129,  0.0025]),
#  tensor([-0.0074,  0.0035, -0.0129,  0.0025,  0.0103]),
#  tensor([ 3.4928e-03, -1.2907e-02,  2.4510e-03,  1.0265e-02, -9.3118e-06]),
#  tensor([-1.2907e-02,  2.4510e-03,  1.0265e-02, -9.3118e-06,  1.2046e-03]),
#  tensor([ 2.4510e-03,  1.0265e-02, -9.3118e-06,  1.2046e-03,  1.2574e-02]),
#  tensor([ 1.0265e-02, -9.3118e-06,  1.2046e-03,  1.2574e-02, -1.1238e-02]),
#  tensor([-9.3118e-06,  1.2046e-03,  1.2574e-02, -1.1238e-02,  4.6855e-03]),
#  tensor([ 0.0012,  0.0126, -0.0112,  0.0047, -0.0380]),
#  tensor([ 0.0126, -0.0112,  0.0047, -0.0380,  0.0027]),
#  tensor([-0.0112,  0.0047, -0.0380,  0.0027,  0.0001]),
#  tensor([ 0.0047, -0.0380,  0.0027,  0.0001, -0.0030]),
#  tensor([-0.0380,  0.0027,  0.0001, -0.0030, -0.0096]),
#  tensor([ 0.0027,  0.0001, -0.0030, -0.0096,  0.0076]),
#  tensor([ 0.0001, -0.0030, -0.0096,  0.0076,  0.0001]),
#  tensor([-0.0030, -0.0096,  0.0076,  0.0001,  0.0099]),
#  tensor([-0.0096,  0.0076,  0.0001,  0.0099, -0.0087]),
#  tensor([ 0.0076,  0.0001,  0.0099, -0.0087,  0.0718]),
#  tensor([ 0.0001,  0.0099, -0.0087,  0.0718,  0.0284]),
#  tensor([ 0.0099, -0.0087,  0.0718,  0.0284,  0.0387]),
#  tensor([-0.0087,  0.0718,  0.0284,  0.0387,  0.0053]),
#  tensor([ 0.0718,  0.0284,  0.0387,  0.0053, -0.0152]),
#  tensor([ 0.0284,  0.0387,  0.0053, -0.0152,  0.0094]),
#  tensor([ 0.0387,  0.0053, -0.0152,  0.0094,  0.0040]),
#  tensor([ 0.0053, -0.0152,  0.0094,  0.0040,  0.0035]),
#  tensor([-0.0152,  0.0094,  0.0040,  0.0035,  0.0043]),
#  tensor([0.0094, 0.0040, 0.0035, 0.0043, 0.0031]),
#  tensor([0.0040, 0.0035, 0.0043, 0.0031, 0.0020]),
#  tensor([ 0.0035,  0.0043,  0.0031,  0.0020, -0.0172]),
#  tensor([ 0.0043,  0.0031,  0.0020, -0.0172,  0.0031]),
#  tensor([ 0.0031,  0.0020, -0.0172,  0.0031,  0.0093]),
#  tensor([ 0.0020, -0.0172,  0.0031,  0.0093,  0.0204]),
#  tensor([-0.0172,  0.0031,  0.0093,  0.0204, -0.0012]),
#  tensor([ 0.0031,  0.0093,  0.0204, -0.0012,  0.0013]),
#  tensor([ 0.0093,  0.0204, -0.0012,  0.0013,  0.0067]),
#  tensor([ 0.0204, -0.0012,  0.0013,  0.0067,  0.0165]),
#  tensor([-0.0012,  0.0013,  0.0067,  0.0165,  0.0163]),
#  tensor([ 0.0013,  0.0067,  0.0165,  0.0163, -0.0256]),
#  tensor([ 0.0067,  0.0165,  0.0163, -0.0256, -0.0075]),
#  tensor([ 0.0165,  0.0163, -0.0256, -0.0075,  0.0125]),
#  tensor([ 0.0163, -0.0256, -0.0075,  0.0125, -0.0096]),
#  tensor([-0.0256, -0.0075,  0.0125, -0.0096,  0.0038]),
#  tensor([-0.0075,  0.0125, -0.0096,  0.0038,  0.0100]),
#  tensor([ 0.0125, -0.0096,  0.0038,  0.0100, -0.0017]),
#  tensor([-0.0096,  0.0038,  0.0100, -0.0017,  0.0136]),
#  tensor([ 0.0038,  0.0100, -0.0017,  0.0136, -0.0032]),
#  tensor([ 0.0100, -0.0017,  0.0136, -0.0032, -0.0110]),
#  tensor([-0.0017,  0.0136, -0.0032, -0.0110,  0.0002]),
#  tensor([ 0.0136, -0.0032, -0.0110,  0.0002,  0.0040]),
#  tensor([-0.0032, -0.0110,  0.0002,  0.0040, -0.0108]),
#  tensor([-0.0110,  0.0002,  0.0040, -0.0108, -0.0070]),
#  tensor([ 0.0002,  0.0040, -0.0108, -0.0070, -0.0037]),
#  tensor([ 0.0040, -0.0108, -0.0070, -0.0037,  0.0077]),
#  tensor([-0.0108, -0.0070, -0.0037,  0.0077,  0.0149]),
#  tensor([-0.0070, -0.0037,  0.0077,  0.0149, -0.0078]),
#  tensor([-0.0037,  0.0077,  0.0149, -0.0078, -0.0098]),
#  tensor([ 0.0077,  0.0149, -0.0078, -0.0098, -0.0369]),
#  tensor([ 0.0149, -0.0078, -0.0098, -0.0369,  0.0089]),
#  tensor([-0.0078, -0.0098, -0.0369,  0.0089,  0.0073]),
#  tensor([-0.0098, -0.0369,  0.0089,  0.0073, -0.0066]),
#  tensor([-0.0369,  0.0089,  0.0073, -0.0066,  0.0020]),
#  tensor([ 0.0089,  0.0073, -0.0066,  0.0020, -0.0086]),
#  tensor([ 0.0073, -0.0066,  0.0020, -0.0086,  0.0033]),
#  tensor([-0.0066,  0.0020, -0.0086,  0.0033, -0.0074]),
#  tensor([ 0.0020, -0.0086,  0.0033, -0.0074,  0.0130]),
#  tensor([-0.0086,  0.0033, -0.0074,  0.0130, -0.0034]),
#  tensor([ 0.0033, -0.0074,  0.0130, -0.0034,  0.0053]),
#  tensor([-0.0074,  0.0130, -0.0034,  0.0053,  0.0046]),
#  tensor([ 0.0130, -0.0034,  0.0053,  0.0046, -0.0529]),
#  tensor([-0.0034,  0.0053,  0.0046, -0.0529, -0.0124]),
#  tensor([ 0.0053,  0.0046, -0.0529, -0.0124, -0.0206]),
#  tensor([ 0.0046, -0.0529, -0.0124, -0.0206, -0.0077]),
#  tensor([-0.0529, -0.0124, -0.0206, -0.0077, -0.0099]),
#  tensor([-0.0124, -0.0206, -0.0077, -0.0099, -0.0048]),
#  tensor([-0.0206, -0.0077, -0.0099, -0.0048,  0.0189]),
#  tensor([-0.0077, -0.0099, -0.0048,  0.0189, -0.0056]),
#  tensor([-0.0099, -0.0048,  0.0189, -0.0056,  0.0033]),
#  tensor([-0.0048,  0.0189, -0.0056,  0.0033,  0.0003]),
#  tensor([ 0.0189, -0.0056,  0.0033,  0.0003,  0.0130]),
#  tensor([-0.0056,  0.0033,  0.0003,  0.0130,  0.0139]),
#  tensor([0.0033, 0.0003, 0.0130, 0.0139, 0.0060]),
#  tensor([0.0003, 0.0130, 0.0139, 0.0060, 0.0006]),
#  tensor([0.0130, 0.0139, 0.0060, 0.0006, 0.0242]),
#  tensor([ 0.0139,  0.0060,  0.0006,  0.0242, -0.0032]),
#  tensor([ 0.0060,  0.0006,  0.0242, -0.0032, -0.0031]),
#  tensor([ 0.0006,  0.0242, -0.0032, -0.0031,  0.0014]),
#  tensor([ 0.0242, -0.0032, -0.0031,  0.0014,  0.0036]),
#  tensor([-0.0032, -0.0031,  0.0014,  0.0036,  0.0070]),
#  tensor([-0.0031,  0.0014,  0.0036,  0.0070, -0.0002]),
#  tensor([ 0.0014,  0.0036,  0.0070, -0.0002,  0.0018]),
#  tensor([ 0.0036,  0.0070, -0.0002,  0.0018, -0.0121]),
#  tensor([ 0.0070, -0.0002,  0.0018, -0.0121,  0.0185]),
#  tensor([-0.0002,  0.0018, -0.0121,  0.0185, -0.0113]),
#  tensor([ 0.0018, -0.0121,  0.0185, -0.0113, -0.0056]),
#  tensor([-0.0121,  0.0185, -0.0113, -0.0056, -0.0034]),
#  tensor([ 0.0185, -0.0113, -0.0056, -0.0034, -0.0024]),
#  tensor([-0.0113, -0.0056, -0.0034, -0.0024,  0.0056]),
#  tensor([-0.0056, -0.0034, -0.0024,  0.0056, -0.0082]),
#  tensor([-0.0034, -0.0024,  0.0056, -0.0082,  0.0089]),
#  tensor([-0.0024,  0.0056, -0.0082,  0.0089,  0.0077]),
#  tensor([ 0.0056, -0.0082,  0.0089,  0.0077, -0.0021]),
#  tensor([-0.0082,  0.0089,  0.0077, -0.0021,  0.0080]),
#  tensor([ 0.0089,  0.0077, -0.0021,  0.0080,  0.0026]),
#  tensor([ 0.0077, -0.0021,  0.0080,  0.0026, -0.0359]),
#  tensor([-0.0021,  0.0080,  0.0026, -0.0359, -0.0015]),
#  tensor([ 0.0080,  0.0026, -0.0359, -0.0015, -0.0095]),
#  tensor([ 0.0026, -0.0359, -0.0015, -0.0095,  0.0027]),
#  tensor([-0.0359, -0.0015, -0.0095,  0.0027, -0.0086]),
#  tensor([-0.0015, -0.0095,  0.0027, -0.0086, -0.0054]),
#  tensor([-0.0095,  0.0027, -0.0086, -0.0054, -0.0030]),
#  tensor([ 0.0027, -0.0086, -0.0054, -0.0030,  0.0112]),
#  tensor([-0.0086, -0.0054, -0.0030,  0.0112, -0.0069]),
#  tensor([-0.0054, -0.0030,  0.0112, -0.0069,  0.0042]),
#  tensor([-0.0030,  0.0112, -0.0069,  0.0042, -0.0009]),
#  tensor([ 0.0112, -0.0069,  0.0042, -0.0009,  0.0007]),
#  tensor([-0.0069,  0.0042, -0.0009,  0.0007,  0.0009]),
#  tensor([ 0.0042, -0.0009,  0.0007,  0.0009,  0.0086]),
#  tensor([-0.0009,  0.0007,  0.0009,  0.0086,  0.0069]),
#  tensor([0.0007, 0.0009, 0.0086, 0.0069, 0.0053]),
#  tensor([0.0009, 0.0086, 0.0069, 0.0053, 0.0080]),
#  tensor([ 0.0086,  0.0069,  0.0053,  0.0080, -0.0039]),
#  tensor([ 0.0069,  0.0053,  0.0080, -0.0039,  0.0065]),
#  tensor([ 0.0053,  0.0080, -0.0039,  0.0065, -0.0027]),
#  tensor([ 0.0080, -0.0039,  0.0065, -0.0027,  0.0172]),
#  tensor([-0.0039,  0.0065, -0.0027,  0.0172, -0.0030]),
#  tensor([ 0.0065, -0.0027,  0.0172, -0.0030,  0.0076]),
#  tensor([-0.0027,  0.0172, -0.0030,  0.0076,  0.0069]),
#  tensor([ 0.0172, -0.0030,  0.0076,  0.0069, -0.0071]),
#  tensor([-0.0030,  0.0076,  0.0069, -0.0071,  0.0117]),
#  tensor([ 0.0076,  0.0069, -0.0071,  0.0117, -0.0419]),
#  tensor([ 0.0069, -0.0071,  0.0117, -0.0419,  0.0082]),
#  tensor([-0.0071,  0.0117, -0.0419,  0.0082,  0.0051]),
#  tensor([ 0.0117, -0.0419,  0.0082,  0.0051,  0.0052]),
#  tensor([-0.0419,  0.0082,  0.0051,  0.0052, -0.0038]),
#  tensor([ 0.0082,  0.0051,  0.0052, -0.0038,  0.0107]),
#  tensor([ 0.0051,  0.0052, -0.0038,  0.0107,  0.0067]),
#  tensor([ 0.0052, -0.0038,  0.0107,  0.0067, -0.0011]),
#  tensor([-0.0038,  0.0107,  0.0067, -0.0011,  0.0016]),
#  tensor([ 0.0107,  0.0067, -0.0011,  0.0016, -0.0118]),
#  tensor([ 0.0067, -0.0011,  0.0016, -0.0118,  0.0066]),
#  tensor([-0.0011,  0.0016, -0.0118,  0.0066,  0.0074]),
#  tensor([ 0.0016, -0.0118,  0.0066,  0.0074, -0.0111]),
#  tensor([-0.0118,  0.0066,  0.0074, -0.0111,  0.0001]),
#  tensor([ 0.0066,  0.0074, -0.0111,  0.0001,  0.0111]),
#  tensor([ 0.0074, -0.0111,  0.0001,  0.0111, -0.0031]),
#  tensor([-0.0111,  0.0001,  0.0111, -0.0031, -0.0362]),
#  tensor([ 0.0001,  0.0111, -0.0031, -0.0362,  0.0069]),
#  tensor([ 0.0111, -0.0031, -0.0362,  0.0069,  0.0132]),
#  tensor([-0.0031, -0.0362,  0.0069,  0.0132,  0.0095]),
#  tensor([-0.0362,  0.0069,  0.0132,  0.0095, -0.0034]),
#  tensor([ 0.0069,  0.0132,  0.0095, -0.0034, -0.0335]),
#  tensor([ 0.0132,  0.0095, -0.0034, -0.0335,  0.0142]),
#  tensor([ 0.0095, -0.0034, -0.0335,  0.0142,  0.0005]),
#  tensor([-0.0034, -0.0335,  0.0142,  0.0005,  0.0011]),
#  tensor([-0.0335,  0.0142,  0.0005,  0.0011,  0.0094]),
#  tensor([0.0142, 0.0005, 0.0011, 0.0094, 0.0193]),
#  tensor([ 0.0005,  0.0011,  0.0094,  0.0193, -0.0038]),
#  tensor([ 0.0011,  0.0094,  0.0193, -0.0038,  0.0049]),
#  tensor([ 0.0094,  0.0193, -0.0038,  0.0049, -0.0114]),
#  tensor([ 0.0193, -0.0038,  0.0049, -0.0114,  0.0118]),
#  tensor([-0.0038,  0.0049, -0.0114,  0.0118,  0.0008]),
#  tensor([ 0.0049, -0.0114,  0.0118,  0.0008,  0.0182]),
#  tensor([-0.0114,  0.0118,  0.0008,  0.0182,  0.0088]),
#  tensor([0.0118, 0.0008, 0.0182, 0.0088, 0.0001]),
#  tensor([ 0.0008,  0.0182,  0.0088,  0.0001, -0.0017]),
#  tensor([ 0.0182,  0.0088,  0.0001, -0.0017,  0.0001]),
#  tensor([ 0.0088,  0.0001, -0.0017,  0.0001,  0.0013]),
#  tensor([ 0.0001, -0.0017,  0.0001,  0.0013,  0.0092]),
#  tensor([-0.0017,  0.0001,  0.0013,  0.0092, -0.0093]),
#  tensor([ 0.0001,  0.0013,  0.0092, -0.0093, -0.0041]),
#  tensor([ 0.0013,  0.0092, -0.0093, -0.0041,  0.0022]),
#  tensor([ 0.0092, -0.0093, -0.0041,  0.0022,  0.0074]),
#  tensor([-0.0093, -0.0041,  0.0022,  0.0074,  0.0012]),
#  tensor([-0.0041,  0.0022,  0.0074,  0.0012,  0.0035]),
#  tensor([0.0022, 0.0074, 0.0012, 0.0035, 0.0128]),
#  tensor([ 0.0074,  0.0012,  0.0035,  0.0128, -0.0135]),
#  tensor([ 0.0012,  0.0035,  0.0128, -0.0135,  0.0024]),
#  tensor([ 0.0035,  0.0128, -0.0135,  0.0024,  0.0120]),
#  tensor([ 0.0128, -0.0135,  0.0024,  0.0120,  0.0028]),
#  tensor([-0.0135,  0.0024,  0.0120,  0.0028, -0.0144]),
#  tensor([ 0.0024,  0.0120,  0.0028, -0.0144,  0.0260]),
#  tensor([ 0.0120,  0.0028, -0.0144,  0.0260,  0.0117]),
#  tensor([ 0.0028, -0.0144,  0.0260,  0.0117, -0.0246]),
#  tensor([-0.0144,  0.0260,  0.0117, -0.0246,  0.0056]),
#  tensor([ 0.0260,  0.0117, -0.0246,  0.0056,  0.0477]),
#  tensor([ 0.0117, -0.0246,  0.0056,  0.0477,  0.0131]),
#  tensor([-0.0246,  0.0056,  0.0477,  0.0131, -0.0009]),
#  tensor([ 0.0056,  0.0477,  0.0131, -0.0009, -0.0007]),
#  tensor([ 0.0477,  0.0131, -0.0009, -0.0007,  0.0087]),
#  tensor([ 0.0131, -0.0009, -0.0007,  0.0087,  0.0033]),
#  tensor([-0.0009, -0.0007,  0.0087,  0.0033, -0.0031]),
#  tensor([-0.0007,  0.0087,  0.0033, -0.0031,  0.0033]),
#  tensor([ 0.0087,  0.0033, -0.0031,  0.0033,  0.0336]),
#  tensor([ 0.0033, -0.0031,  0.0033,  0.0336,  0.0130]),
#  tensor([-0.0031,  0.0033,  0.0336,  0.0130, -0.0265]),
#  tensor([ 0.0033,  0.0336,  0.0130, -0.0265, -0.0039]),
#  tensor([ 0.0336,  0.0130, -0.0265, -0.0039,  0.0045]),
#  tensor([ 0.0130, -0.0265, -0.0039,  0.0045,  0.0052]),
#  tensor([-0.0265, -0.0039,  0.0045,  0.0052, -0.0065]),
#  tensor([-0.0039,  0.0045,  0.0052, -0.0065,  0.0005]),
#  tensor([ 0.0045,  0.0052, -0.0065,  0.0005,  0.0017]),
#  tensor([ 0.0052, -0.0065,  0.0005,  0.0017,  0.0070]),
#  tensor([-0.0065,  0.0005,  0.0017,  0.0070, -0.0022]),
#  tensor([ 0.0005,  0.0017,  0.0070, -0.0022, -0.0001]),
#  tensor([ 0.0017,  0.0070, -0.0022, -0.0001, -0.0040]),
#  tensor([ 0.0070, -0.0022, -0.0001, -0.0040, -0.0008]),
#  tensor([-0.0022, -0.0001, -0.0040, -0.0008,  0.0127]),
#  tensor([-0.0001, -0.0040, -0.0008,  0.0127,  0.0007]),
#  tensor([-0.0040, -0.0008,  0.0127,  0.0007,  0.0028]),
#  tensor([-0.0008,  0.0127,  0.0007,  0.0028, -0.0182]),
#  tensor([ 0.0127,  0.0007,  0.0028, -0.0182, -0.0038]),
#  tensor([ 0.0007,  0.0028, -0.0182, -0.0038,  0.0008]),
#  tensor([ 0.0028, -0.0182, -0.0038,  0.0008,  0.0150]),
#  tensor([-0.0182, -0.0038,  0.0008,  0.0150, -0.0091]),
#  tensor([-0.0038,  0.0008,  0.0150, -0.0091, -0.0047]),
#  tensor([ 0.0008,  0.0150, -0.0091, -0.0047,  0.0174]),
#  tensor([ 0.0150, -0.0091, -0.0047,  0.0174,  0.0028]),
#  tensor([-0.0091, -0.0047,  0.0174,  0.0028, -0.0013]),
#  tensor([-0.0047,  0.0174,  0.0028, -0.0013, -0.0025]),
#  tensor([ 0.0174,  0.0028, -0.0013, -0.0025,  0.0064]),
#  tensor([ 0.0028, -0.0013, -0.0025,  0.0064, -0.0010]),
#  tensor([-0.0013, -0.0025,  0.0064, -0.0010, -0.0178]),
#  tensor([-2.5261e-03,  6.4148e-03, -9.7575e-04, -1.7826e-02, -2.8722e-05]),
#  tensor([ 6.4148e-03, -9.7575e-04, -1.7826e-02, -2.8722e-05, -6.4318e-03]),
#  tensor([-9.7575e-04, -1.7826e-02, -2.8722e-05, -6.4318e-03, -1.4874e-03]),
#  tensor([-1.7826e-02, -2.8722e-05, -6.4318e-03, -1.4874e-03,  1.4825e-02]),
#  tensor([-2.8722e-05, -6.4318e-03, -1.4874e-03,  1.4825e-02,  1.8087e-02]),
#  tensor([-0.0064, -0.0015,  0.0148,  0.0181, -0.0003]),
#  tensor([-1.4874e-03,  1.4825e-02,  1.8087e-02, -2.6482e-04, -2.9167e-05]),
#  tensor([ 1.4825e-02,  1.8087e-02, -2.6482e-04, -2.9167e-05,  5.3112e-03]),
#  tensor([ 1.8087e-02, -2.6482e-04, -2.9167e-05,  5.3112e-03,  7.4077e-03]),
#  tensor([-2.6482e-04, -2.9167e-05,  5.3112e-03,  7.4077e-03, -2.9574e-03]),
#  tensor([-2.9167e-05,  5.3112e-03,  7.4077e-03, -2.9574e-03,  7.2576e-03]),
#  tensor([ 0.0053,  0.0074, -0.0030,  0.0073,  0.0029]),
#  tensor([ 0.0074, -0.0030,  0.0073,  0.0029,  0.0083]),
#  tensor([-0.0030,  0.0073,  0.0029,  0.0083,  0.0072]),
#  tensor([ 0.0073,  0.0029,  0.0083,  0.0072, -0.0087]),
#  tensor([ 0.0029,  0.0083,  0.0072, -0.0087,  0.0176]),
#  tensor([ 0.0083,  0.0072, -0.0087,  0.0176,  0.0231]),
#  tensor([ 0.0072, -0.0087,  0.0176,  0.0231,  0.0057]),
#  tensor([-0.0087,  0.0176,  0.0231,  0.0057,  0.0003]),
#  tensor([0.0176, 0.0231, 0.0057, 0.0003, 0.0026]),
#  tensor([0.0231, 0.0057, 0.0003, 0.0026, 0.0054]),
#  tensor([0.0057, 0.0003, 0.0026, 0.0054, 0.0037]),
#  tensor([ 0.0003,  0.0026,  0.0054,  0.0037, -0.0004]),
#  tensor([ 0.0026,  0.0054,  0.0037, -0.0004,  0.0021]),
#  tensor([ 0.0054,  0.0037, -0.0004,  0.0021,  0.0072]),
#  tensor([ 0.0037, -0.0004,  0.0021,  0.0072,  0.0173]),
#  tensor([-0.0004,  0.0021,  0.0072,  0.0173,  0.0051]),
#  tensor([ 0.0021,  0.0072,  0.0173,  0.0051, -0.0013]),
#  tensor([ 0.0072,  0.0173,  0.0051, -0.0013, -0.0010]),
#  tensor([ 0.0173,  0.0051, -0.0013, -0.0010,  0.0108]),
#  tensor([ 0.0051, -0.0013, -0.0010,  0.0108, -0.0014]),
#  tensor([-0.0013, -0.0010,  0.0108, -0.0014,  0.0128]),
#  tensor([-0.0010,  0.0108, -0.0014,  0.0128, -0.0076]),
#  tensor([ 0.0108, -0.0014,  0.0128, -0.0076,  0.0036]),
#  tensor([-0.0014,  0.0128, -0.0076,  0.0036, -0.0138]),
#  tensor([ 0.0128, -0.0076,  0.0036, -0.0138, -0.0009]),
#  tensor([-0.0076,  0.0036, -0.0138, -0.0009, -0.0115]),
#  tensor([ 0.0036, -0.0138, -0.0009, -0.0115, -0.0166]),
#  tensor([-0.0138, -0.0009, -0.0115, -0.0166,  0.0052]),
#  tensor([-0.0009, -0.0115, -0.0166,  0.0052, -0.0036]),
#  tensor([-0.0115, -0.0166,  0.0052, -0.0036,  0.0222]),
#  tensor([-0.0166,  0.0052, -0.0036,  0.0222, -0.0007]),
#  tensor([ 0.0052, -0.0036,  0.0222, -0.0007,  0.0040]),
#  tensor([-0.0036,  0.0222, -0.0007,  0.0040, -0.0126]),
#  tensor([ 0.0222, -0.0007,  0.0040, -0.0126, -0.0029]),
#  tensor([-0.0007,  0.0040, -0.0126, -0.0029, -0.0083]),
#  tensor([ 0.0040, -0.0126, -0.0029, -0.0083,  0.0091]),
#  tensor([-0.0126, -0.0029, -0.0083,  0.0091, -0.0017]),
#  tensor([-0.0029, -0.0083,  0.0091, -0.0017,  0.0114]),
#  tensor([-0.0083,  0.0091, -0.0017,  0.0114, -0.0014]),
#  tensor([ 0.0091, -0.0017,  0.0114, -0.0014,  0.0125]),
#  tensor([-0.0017,  0.0114, -0.0014,  0.0125,  0.0047]),
#  tensor([ 0.0114, -0.0014,  0.0125,  0.0047,  0.0033]),
#  tensor([-0.0014,  0.0125,  0.0047,  0.0033,  0.0148]),
#  tensor([ 0.0125,  0.0047,  0.0033,  0.0148, -0.0001]),
#  tensor([ 0.0047,  0.0033,  0.0148, -0.0001,  0.0016]),
#  tensor([ 0.0033,  0.0148, -0.0001,  0.0016,  0.0009]),
#  tensor([ 0.0148, -0.0001,  0.0016,  0.0009,  0.0181]),
#  tensor([-0.0001,  0.0016,  0.0009,  0.0181,  0.0152]),
#  tensor([0.0016, 0.0009, 0.0181, 0.0152, 0.0163]),
#  tensor([ 0.0009,  0.0181,  0.0152,  0.0163, -0.0013]),
#  tensor([ 0.0181,  0.0152,  0.0163, -0.0013,  0.0003]),
#  tensor([ 0.0152,  0.0163, -0.0013,  0.0003, -0.0115]),
#  tensor([ 0.0163, -0.0013,  0.0003, -0.0115,  0.0014]),
#  tensor([-0.0013,  0.0003, -0.0115,  0.0014,  0.0093]),
#  tensor([ 2.5693e-04, -1.1511e-02,  1.4410e-03,  9.2975e-03,  6.1977e-05]),
#  tensor([-1.1511e-02,  1.4410e-03,  9.2975e-03,  6.1977e-05, -8.7944e-03]),
#  tensor([ 1.4410e-03,  9.2975e-03,  6.1977e-05, -8.7944e-03,  7.7214e-03]),
#  tensor([ 9.2975e-03,  6.1977e-05, -8.7944e-03,  7.7214e-03, -1.6913e-03]),
#  tensor([ 6.1977e-05, -8.7944e-03,  7.7214e-03, -1.6913e-03, -3.0782e-03]),
#  tensor([-0.0088,  0.0077, -0.0017, -0.0031,  0.0096]),
#  tensor([ 0.0077, -0.0017, -0.0031,  0.0096,  0.0084]),
#  tensor([-0.0017, -0.0031,  0.0096,  0.0084, -0.0029]),
#  tensor([-0.0031,  0.0096,  0.0084, -0.0029,  0.0060]),
#  tensor([ 0.0096,  0.0084, -0.0029,  0.0060,  0.0081]),
#  tensor([ 0.0084, -0.0029,  0.0060,  0.0081,  0.0061]),
#  tensor([-0.0029,  0.0060,  0.0081,  0.0061,  0.0011]),
#  tensor([ 0.0060,  0.0081,  0.0061,  0.0011, -0.0033]),
#  tensor([ 0.0081,  0.0061,  0.0011, -0.0033,  0.0030]),
#  tensor([ 0.0061,  0.0011, -0.0033,  0.0030, -0.0039]),
#  tensor([ 0.0011, -0.0033,  0.0030, -0.0039, -0.0177]),
#  tensor([-0.0033,  0.0030, -0.0039, -0.0177,  0.0136]),
#  tensor([ 0.0030, -0.0039, -0.0177,  0.0136,  0.0078]),
#  tensor([-0.0039, -0.0177,  0.0136,  0.0078,  0.0182]),
#  tensor([-0.0177,  0.0136,  0.0078,  0.0182,  0.0247]),
#  tensor([0.0136, 0.0078, 0.0182, 0.0247, 0.0170]),
#  tensor([0.0078, 0.0182, 0.0247, 0.0170, 0.0046]),
#  tensor([0.0182, 0.0247, 0.0170, 0.0046, 0.0070]),
#  tensor([0.0247, 0.0170, 0.0046, 0.0070, 0.0202]),
#  tensor([ 0.0170,  0.0046,  0.0070,  0.0202, -0.0077]),
#  tensor([ 0.0046,  0.0070,  0.0202, -0.0077,  0.0166]),
#  tensor([ 0.0070,  0.0202, -0.0077,  0.0166, -0.0051]),
#  tensor([ 0.0202, -0.0077,  0.0166, -0.0051,  0.0134]),
#  tensor([-0.0077,  0.0166, -0.0051,  0.0134,  0.0004]),
#  tensor([ 0.0166, -0.0051,  0.0134,  0.0004,  0.0058]),
#  tensor([-0.0051,  0.0134,  0.0004,  0.0058, -0.0032]),
#  tensor([ 0.0134,  0.0004,  0.0058, -0.0032, -0.0031]),
#  tensor([ 0.0004,  0.0058, -0.0032, -0.0031,  0.0225]),
#  tensor([ 0.0058, -0.0032, -0.0031,  0.0225, -0.0204]),
#  tensor([-0.0032, -0.0031,  0.0225, -0.0204, -0.0429]),
#  tensor([-0.0031,  0.0225, -0.0204, -0.0429, -0.0079]),
#  tensor([ 0.0225, -0.0204, -0.0429, -0.0079,  0.0047]),
#  tensor([-0.0204, -0.0429, -0.0079,  0.0047, -0.0203]),
#  tensor([-0.0429, -0.0079,  0.0047, -0.0203, -0.0423]),
#  tensor([-0.0079,  0.0047, -0.0203, -0.0423,  0.0163]),
#  tensor([ 0.0047, -0.0203, -0.0423,  0.0163, -0.0042]),
#  tensor([-0.0203, -0.0423,  0.0163, -0.0042, -0.0426]),
#  tensor([-0.0423,  0.0163, -0.0042, -0.0426,  0.0139]),
#  tensor([ 0.0163, -0.0042, -0.0426,  0.0139,  0.0147]),
#  tensor([-0.0042, -0.0426,  0.0139,  0.0147,  0.0076]),
#  tensor([-0.0426,  0.0139,  0.0147,  0.0076,  0.0245]),
#  tensor([0.0139, 0.0147, 0.0076, 0.0245, 0.0114]),
#  tensor([0.0147, 0.0076, 0.0245, 0.0114, 0.0084]),
#  tensor([ 0.0076,  0.0245,  0.0114,  0.0084, -0.0053]),
#  tensor([ 0.0245,  0.0114,  0.0084, -0.0053,  0.0003]),
#  tensor([ 0.0114,  0.0084, -0.0053,  0.0003,  0.0042]),
#  tensor([ 0.0084, -0.0053,  0.0003,  0.0042,  0.0170]),
#  tensor([-0.0053,  0.0003,  0.0042,  0.0170,  0.0164]),
#  tensor([ 0.0003,  0.0042,  0.0170,  0.0164, -0.0155]),
#  tensor([ 0.0042,  0.0170,  0.0164, -0.0155, -0.0044]),
#  tensor([ 0.0170,  0.0164, -0.0155, -0.0044, -0.0163]),
#  tensor([ 0.0164, -0.0155, -0.0044, -0.0163,  0.0022]),
#  tensor([-0.0155, -0.0044, -0.0163,  0.0022,  0.0137]),
#  tensor([-0.0044, -0.0163,  0.0022,  0.0137,  0.0135]),
#  tensor([-0.0163,  0.0022,  0.0137,  0.0135, -0.0024]),
#  tensor([ 0.0022,  0.0137,  0.0135, -0.0024,  0.0095]),
#  tensor([ 0.0137,  0.0135, -0.0024,  0.0095,  0.0300]),
#  tensor([ 0.0135, -0.0024,  0.0095,  0.0300, -0.0044]),
#  tensor([-0.0024,  0.0095,  0.0300, -0.0044, -0.0011]),
#  tensor([ 0.0095,  0.0300, -0.0044, -0.0011, -0.0066]),
#  tensor([ 0.0300, -0.0044, -0.0011, -0.0066, -0.0008]),
#  tensor([-0.0044, -0.0011, -0.0066, -0.0008,  0.0011]),
#  tensor([-0.0011, -0.0066, -0.0008,  0.0011, -0.0189]),
#  tensor([-0.0066, -0.0008,  0.0011, -0.0189, -0.0120]),
#  tensor([-0.0008,  0.0011, -0.0189, -0.0120,  0.0051]),
#  tensor([ 0.0011, -0.0189, -0.0120,  0.0051, -0.0439]),
#  tensor([-0.0189, -0.0120,  0.0051, -0.0439, -0.0278]),
#  tensor([-0.0120,  0.0051, -0.0439, -0.0278,  0.0352]),
#  tensor([ 0.0051, -0.0439, -0.0278,  0.0352, -0.0207]),
#  tensor([-0.0439, -0.0278,  0.0352, -0.0207, -0.0030]),
#  tensor([-0.0278,  0.0352, -0.0207, -0.0030,  0.0206]),
#  tensor([ 0.0352, -0.0207, -0.0030,  0.0206, -0.0306]),
#  tensor([-0.0207, -0.0030,  0.0206, -0.0306,  0.0169]),
#  tensor([-0.0030,  0.0206, -0.0306,  0.0169,  0.0106]),
#  tensor([ 0.0206, -0.0306,  0.0169,  0.0106, -0.0004]),
#  tensor([-0.0306,  0.0169,  0.0106, -0.0004, -0.0293]),
#  tensor([ 0.0169,  0.0106, -0.0004, -0.0293,  0.0052]),
#  tensor([ 0.0106, -0.0004, -0.0293,  0.0052,  0.0172]),
#  tensor([-0.0004, -0.0293,  0.0052,  0.0172, -0.0051]),
#  tensor([-0.0293,  0.0052,  0.0172, -0.0051,  0.0174]),
#  tensor([ 0.0052,  0.0172, -0.0051,  0.0174, -0.0087]),
#  tensor([ 0.0172, -0.0051,  0.0174, -0.0087,  0.0078]),
#  tensor([-0.0051,  0.0174, -0.0087,  0.0078,  0.0118]),
#  tensor([ 0.0174, -0.0087,  0.0078,  0.0118, -0.0033]),
#  tensor([-0.0087,  0.0078,  0.0118, -0.0033, -0.0005]),
#  tensor([ 0.0078,  0.0118, -0.0033, -0.0005, -0.0036]),
#  tensor([ 0.0118, -0.0033, -0.0005, -0.0036,  0.0016]),
#  tensor([-0.0033, -0.0005, -0.0036,  0.0016, -0.0116]),
#  tensor([-0.0005, -0.0036,  0.0016, -0.0116,  0.0338]),
#  tensor([-0.0036,  0.0016, -0.0116,  0.0338,  0.0117]),
#  tensor([ 0.0016, -0.0116,  0.0338,  0.0117,  0.0153]),
#  tensor([-0.0116,  0.0338,  0.0117,  0.0153, -0.0018]),
#  tensor([ 0.0338,  0.0117,  0.0153, -0.0018, -0.0226]),
#  tensor([ 0.0117,  0.0153, -0.0018, -0.0226, -0.0059]),
#  tensor([ 0.0153, -0.0018, -0.0226, -0.0059, -0.0105]),
#  tensor([-0.0018, -0.0226, -0.0059, -0.0105,  0.0231]),
#  tensor([-0.0226, -0.0059, -0.0105,  0.0231,  0.0133]),
#  tensor([-0.0059, -0.0105,  0.0231,  0.0133,  0.0061]),
#  tensor([-0.0105,  0.0231,  0.0133,  0.0061,  0.0218]),
#  tensor([0.0231, 0.0133, 0.0061, 0.0218, 0.0079]),
#  tensor([0.0133, 0.0061, 0.0218, 0.0079, 0.0053]),
#  tensor([ 0.0061,  0.0218,  0.0079,  0.0053, -0.0018]),
#  tensor([ 0.0218,  0.0079,  0.0053, -0.0018, -0.0074]),
#  tensor([ 0.0079,  0.0053, -0.0018, -0.0074,  0.0308]),
#  tensor([ 0.0053, -0.0018, -0.0074,  0.0308, -0.0010]),
#  tensor([-0.0018, -0.0074,  0.0308, -0.0010, -0.0004]),
#  tensor([-0.0074,  0.0308, -0.0010, -0.0004,  0.0111]),
#  tensor([ 0.0308, -0.0010, -0.0004,  0.0111,  0.0059]),
#  tensor([-0.0010, -0.0004,  0.0111,  0.0059, -0.0091]),
#  tensor([-0.0004,  0.0111,  0.0059, -0.0091, -0.0015]),
#  tensor([ 1.1143e-02,  5.8534e-03, -9.0999e-03, -1.4510e-03, -5.1674e-05]),
#  tensor([ 5.8534e-03, -9.0999e-03, -1.4510e-03, -5.1674e-05, -2.1883e-02]),
#  tensor([-9.0999e-03, -1.4510e-03, -5.1674e-05, -2.1883e-02,  2.9933e-02]),
#  tensor([-1.4510e-03, -5.1674e-05, -2.1883e-02,  2.9933e-02, -7.1661e-03]),
#  tensor([-5.1674e-05, -2.1883e-02,  2.9933e-02, -7.1661e-03,  1.2137e-02]),
#  tensor([-0.0219,  0.0299, -0.0072,  0.0121,  0.0023]),
#  tensor([ 0.0299, -0.0072,  0.0121,  0.0023, -0.0055]),
#  tensor([-0.0072,  0.0121,  0.0023, -0.0055,  0.0299]),
#  tensor([ 0.0121,  0.0023, -0.0055,  0.0299, -0.0077]),
#  tensor([ 0.0023, -0.0055,  0.0299, -0.0077,  0.0060]),
#  tensor([-0.0055,  0.0299, -0.0077,  0.0060, -0.0010]),
#  tensor([ 0.0299, -0.0077,  0.0060, -0.0010,  0.0030]),
#  tensor([-0.0077,  0.0060, -0.0010,  0.0030, -0.0073]),
#  tensor([ 0.0060, -0.0010,  0.0030, -0.0073, -0.0077]),
#  tensor([-0.0010,  0.0030, -0.0073, -0.0077,  0.0083]),
#  tensor([ 0.0030, -0.0073, -0.0077,  0.0083, -0.0079]),
#  tensor([-0.0073, -0.0077,  0.0083, -0.0079, -0.0064]),
#  tensor([-0.0077,  0.0083, -0.0079, -0.0064,  0.0122]),
#  tensor([ 0.0083, -0.0079, -0.0064,  0.0122, -0.0062]),
#  tensor([-0.0079, -0.0064,  0.0122, -0.0062, -0.0055]),
#  tensor([-0.0064,  0.0122, -0.0062, -0.0055, -0.0266]),
#  tensor([ 0.0122, -0.0062, -0.0055, -0.0266, -0.0092]),
#  tensor([-0.0062, -0.0055, -0.0266, -0.0092, -0.0258]),
#  tensor([-0.0055, -0.0266, -0.0092, -0.0258,  0.0006]),
#  tensor([-0.0266, -0.0092, -0.0258,  0.0006,  0.0035]),
#  tensor([-0.0092, -0.0258,  0.0006,  0.0035,  0.0037]),
#  tensor([-0.0258,  0.0006,  0.0035,  0.0037, -0.0068]),
#  tensor([ 0.0006,  0.0035,  0.0037, -0.0068, -0.0021]),
#  tensor([ 3.4914e-03,  3.6504e-03, -6.8334e-03, -2.1276e-03,  3.3745e-05]),
#  tensor([ 3.6504e-03, -6.8334e-03, -2.1276e-03,  3.3745e-05,  2.0292e-02]),
#  tensor([-6.8334e-03, -2.1276e-03,  3.3745e-05,  2.0292e-02,  7.4979e-03]),
#  tensor([-2.1276e-03,  3.3745e-05,  2.0292e-02,  7.4979e-03, -3.1701e-03]),
#  tensor([ 3.3745e-05,  2.0292e-02,  7.4979e-03, -3.1701e-03,  1.2871e-02]),
#  tensor([ 0.0203,  0.0075, -0.0032,  0.0129, -0.0056]),
#  tensor([ 0.0075, -0.0032,  0.0129, -0.0056,  0.0096]),
#  tensor([-0.0032,  0.0129, -0.0056,  0.0096,  0.0002]),
#  tensor([ 0.0129, -0.0056,  0.0096,  0.0002,  0.0144]),
#  tensor([-0.0056,  0.0096,  0.0002,  0.0144, -0.0115]),
#  tensor([ 0.0096,  0.0002,  0.0144, -0.0115, -0.0074]),
#  tensor([ 0.0002,  0.0144, -0.0115, -0.0074,  0.0120]),
#  tensor([ 0.0144, -0.0115, -0.0074,  0.0120, -0.0001]),
#  tensor([-0.0115, -0.0074,  0.0120, -0.0001,  0.0289]),
#  tensor([-0.0074,  0.0120, -0.0001,  0.0289, -0.0258]),
#  tensor([ 0.0120, -0.0001,  0.0289, -0.0258, -0.0214]),
#  tensor([-0.0001,  0.0289, -0.0258, -0.0214, -0.0138]),
#  tensor([ 0.0289, -0.0258, -0.0214, -0.0138,  0.0144]),
#  tensor([-0.0258, -0.0214, -0.0138,  0.0144, -0.0153]),
#  tensor([-0.0214, -0.0138,  0.0144, -0.0153,  0.0014]),
#  tensor([-0.0138,  0.0144, -0.0153,  0.0014, -0.0004]),
#  tensor([ 0.0144, -0.0153,  0.0014, -0.0004,  0.0097]),
#  tensor([-0.0153,  0.0014, -0.0004,  0.0097,  0.0068]),
#  tensor([ 0.0014, -0.0004,  0.0097,  0.0068,  0.0028]),
#  tensor([-0.0004,  0.0097,  0.0068,  0.0028, -0.0068]),
#  tensor([ 0.0097,  0.0068,  0.0028, -0.0068, -0.0148]),
#  tensor([ 0.0068,  0.0028, -0.0068, -0.0148, -0.0048]),
#  tensor([ 0.0028, -0.0068, -0.0148, -0.0048,  0.0084]),
#  tensor([-0.0068, -0.0148, -0.0048,  0.0084, -0.0177]),
#  tensor([-0.0148, -0.0048,  0.0084, -0.0177,  0.0071]),
#  tensor([-0.0048,  0.0084, -0.0177,  0.0071, -0.0062]),
#  tensor([ 0.0084, -0.0177,  0.0071, -0.0062,  0.0007]),
#  tensor([-0.0177,  0.0071, -0.0062,  0.0007,  0.0044]),
#  tensor([ 0.0071, -0.0062,  0.0007,  0.0044, -0.0045]),
#  tensor([-0.0062,  0.0007,  0.0044, -0.0045, -0.0055]),
#  tensor([ 0.0007,  0.0044, -0.0045, -0.0055,  0.0030]),
#  tensor([ 0.0044, -0.0045, -0.0055,  0.0030,  0.0076]),
#  tensor([-0.0045, -0.0055,  0.0030,  0.0076,  0.0017]),
#  tensor([-0.0055,  0.0030,  0.0076,  0.0017, -0.0019]),
#  tensor([ 0.0030,  0.0076,  0.0017, -0.0019, -0.0075]),
#  tensor([ 0.0076,  0.0017, -0.0019, -0.0075,  0.0041]),
#  tensor([ 0.0017, -0.0019, -0.0075,  0.0041, -0.0064]),
#  tensor([-0.0019, -0.0075,  0.0041, -0.0064, -0.0058]),
#  tensor([-0.0075,  0.0041, -0.0064, -0.0058, -0.0109]),
#  tensor([ 0.0041, -0.0064, -0.0058, -0.0109, -0.0489]),
#  tensor([-0.0064, -0.0058, -0.0109, -0.0489,  0.0162]),
#  tensor([-0.0058, -0.0109, -0.0489,  0.0162,  0.0072]),
#  tensor([-0.0109, -0.0489,  0.0162,  0.0072, -0.0013]),
#  tensor([-0.0489,  0.0162,  0.0072, -0.0013, -0.0024]),
#  tensor([ 0.0162,  0.0072, -0.0013, -0.0024,  0.0109]),
#  tensor([ 0.0072, -0.0013, -0.0024,  0.0109, -0.0128]),
#  tensor([-0.0013, -0.0024,  0.0109, -0.0128,  0.0030]),
#  tensor([-0.0024,  0.0109, -0.0128,  0.0030,  0.0147]),
#  tensor([ 0.0109, -0.0128,  0.0030,  0.0147,  0.0057]),
#  tensor([-0.0128,  0.0030,  0.0147,  0.0057,  0.0020]),
#  tensor([ 0.0030,  0.0147,  0.0057,  0.0020, -0.0072]),
#  tensor([ 0.0147,  0.0057,  0.0020, -0.0072, -0.0061]),
#  tensor([ 0.0057,  0.0020, -0.0072, -0.0061, -0.0051]),
#  tensor([ 0.0020, -0.0072, -0.0061, -0.0051,  0.0032]),
#  tensor([-0.0072, -0.0061, -0.0051,  0.0032, -0.0084]),
#  tensor([-0.0061, -0.0051,  0.0032, -0.0084,  0.0062]),
#  tensor([-0.0051,  0.0032, -0.0084,  0.0062,  0.0123]),
#  tensor([ 0.0032, -0.0084,  0.0062,  0.0123,  0.0050]),
#  tensor([-0.0084,  0.0062,  0.0123,  0.0050, -0.0088]),
#  tensor([ 0.0062,  0.0123,  0.0050, -0.0088, -0.0134]),
#  tensor([ 0.0123,  0.0050, -0.0088, -0.0134, -0.0114]),
#  tensor([ 0.0050, -0.0088, -0.0134, -0.0114, -0.0597]),
#  tensor([-0.0088, -0.0134, -0.0114, -0.0597, -0.0300]),
#  tensor([-0.0134, -0.0114, -0.0597, -0.0300,  0.0172]),
#  tensor([-0.0114, -0.0597, -0.0300,  0.0172,  0.0045]),
#  tensor([-0.0597, -0.0300,  0.0172,  0.0045,  0.0128]),
#  tensor([-0.0300,  0.0172,  0.0045,  0.0128,  0.0068]),
#  tensor([ 0.0172,  0.0045,  0.0128,  0.0068, -0.0274]),
#  tensor([ 0.0045,  0.0128,  0.0068, -0.0274,  0.0020]),
#  tensor([ 0.0128,  0.0068, -0.0274,  0.0020, -0.0067]),
#  tensor([ 0.0068, -0.0274,  0.0020, -0.0067, -0.0160]),
#  tensor([-0.0274,  0.0020, -0.0067, -0.0160, -0.0404]),
#  tensor([ 0.0020, -0.0067, -0.0160, -0.0404,  0.0175]),
#  tensor([-0.0067, -0.0160, -0.0404,  0.0175, -0.0173]),
#  tensor([-0.0160, -0.0404,  0.0175, -0.0173, -0.0011]),
#  tensor([-0.0404,  0.0175, -0.0173, -0.0011,  0.0261]),
#  tensor([ 0.0175, -0.0173, -0.0011,  0.0261,  0.0079]),
#  tensor([-0.0173, -0.0011,  0.0261,  0.0079,  0.0106]),
#  tensor([-0.0011,  0.0261,  0.0079,  0.0106, -0.0112]),
#  tensor([ 0.0261,  0.0079,  0.0106, -0.0112,  0.0050]),
#  tensor([ 0.0079,  0.0106, -0.0112,  0.0050,  0.0175]),
#  tensor([ 0.0106, -0.0112,  0.0050,  0.0175,  0.0238]),
#  tensor([-0.0112,  0.0050,  0.0175,  0.0238, -0.0159]),
#  tensor([ 0.0050,  0.0175,  0.0238, -0.0159, -0.0142]),
#  tensor([ 0.0175,  0.0238, -0.0159, -0.0142,  0.0029]),
#  tensor([ 0.0238, -0.0159, -0.0142,  0.0029, -0.0138]),
#  tensor([-0.0159, -0.0142,  0.0029, -0.0138,  0.0160]),
#  tensor([-0.0142,  0.0029, -0.0138,  0.0160, -0.0020]),
#  tensor([ 0.0029, -0.0138,  0.0160, -0.0020, -0.0096]),
#  tensor([-0.0138,  0.0160, -0.0020, -0.0096, -0.0312]),
#  tensor([ 0.0160, -0.0020, -0.0096, -0.0312,  0.0272]),
#  tensor([-0.0020, -0.0096, -0.0312,  0.0272,  0.0014]),
#  tensor([-0.0096, -0.0312,  0.0272,  0.0014,  0.0138]),
#  tensor([-0.0312,  0.0272,  0.0014,  0.0138, -0.0114]),
#  tensor([ 0.0272,  0.0014,  0.0138, -0.0114,  0.0365]),
#  tensor([ 0.0014,  0.0138, -0.0114,  0.0365, -0.0048]),
#  tensor([ 0.0138, -0.0114,  0.0365, -0.0048,  0.0152]),
#  tensor([-0.0114,  0.0365, -0.0048,  0.0152,  0.0021]),
#  tensor([ 0.0365, -0.0048,  0.0152,  0.0021, -0.0433]),
#  tensor([-0.0048,  0.0152,  0.0021, -0.0433, -0.0044]),
#  tensor([ 0.0152,  0.0021, -0.0433, -0.0044, -0.0167]),
#  tensor([ 0.0021, -0.0433, -0.0044, -0.0167, -0.0090]),
#  tensor([-0.0433, -0.0044, -0.0167, -0.0090, -0.0046]),
#  tensor([-0.0044, -0.0167, -0.0090, -0.0046,  0.0216]),
#  tensor([-0.0167, -0.0090, -0.0046,  0.0216, -0.0007]),
#  tensor([-0.0090, -0.0046,  0.0216, -0.0007, -0.0139]),
#  tensor([-0.0046,  0.0216, -0.0007, -0.0139, -0.0103]),
#  tensor([ 0.0216, -0.0007, -0.0139, -0.0103, -0.0026]),
#  tensor([-0.0007, -0.0139, -0.0103, -0.0026, -0.0264]),
#  tensor([-0.0139, -0.0103, -0.0026, -0.0264, -0.0126]),
#  tensor([-0.0103, -0.0026, -0.0264, -0.0126, -0.0060]),
#  tensor([-0.0026, -0.0264, -0.0126, -0.0060, -0.0212]),
#  tensor([-0.0264, -0.0126, -0.0060, -0.0212,  0.0553]),
#  tensor([-0.0126, -0.0060, -0.0212,  0.0553,  0.0185]),
#  tensor([-0.0060, -0.0212,  0.0553,  0.0185,  0.0003]),
#  tensor([-0.0212,  0.0553,  0.0185,  0.0003,  0.0107]),
#  tensor([ 0.0553,  0.0185,  0.0003,  0.0107, -0.0053]),
#  tensor([ 0.0185,  0.0003,  0.0107, -0.0053, -0.0331]),
#  tensor([ 0.0003,  0.0107, -0.0053, -0.0331,  0.0356]),
#  tensor([ 0.0107, -0.0053, -0.0331,  0.0356, -0.0015]),
#  tensor([-0.0053, -0.0331,  0.0356, -0.0015,  0.0051]),
#  tensor([-0.0331,  0.0356, -0.0015,  0.0051,  0.0035]),
#  tensor([ 0.0356, -0.0015,  0.0051,  0.0035, -0.0040]),
#  tensor([-0.0015,  0.0051,  0.0035, -0.0040, -0.0222]),
#  tensor([ 0.0051,  0.0035, -0.0040, -0.0222,  0.0103]),
#  tensor([ 0.0035, -0.0040, -0.0222,  0.0103,  0.0170]),
#  tensor([-0.0040, -0.0222,  0.0103,  0.0170,  0.0271]),
#  tensor([-0.0222,  0.0103,  0.0170,  0.0271, -0.0056]),
#  tensor([ 0.0103,  0.0170,  0.0271, -0.0056,  0.0197]),
#  tensor([ 0.0170,  0.0271, -0.0056,  0.0197, -0.0222]),
#  tensor([ 0.0271, -0.0056,  0.0197, -0.0222, -0.0091]),
#  tensor([-0.0056,  0.0197, -0.0222, -0.0091,  0.0025]),
#  tensor([ 0.0197, -0.0222, -0.0091,  0.0025,  0.0073]),
#  tensor([-0.0222, -0.0091,  0.0025,  0.0073, -0.0011]),
#  tensor([-0.0091,  0.0025,  0.0073, -0.0011, -0.0181]),
#  tensor([ 0.0025,  0.0073, -0.0011, -0.0181, -0.0379]),
#  tensor([ 0.0073, -0.0011, -0.0181, -0.0379,  0.0472]),
#  tensor([-0.0011, -0.0181, -0.0379,  0.0472,  0.0073]),
#  tensor([-0.0181, -0.0379,  0.0472,  0.0073,  0.0108]),
#  tensor([-0.0379,  0.0472,  0.0073,  0.0108, -0.0061]),
#  tensor([ 0.0472,  0.0073,  0.0108, -0.0061, -0.0041]),
#  tensor([ 0.0073,  0.0108, -0.0061, -0.0041, -0.0052]),
#  tensor([ 0.0108, -0.0061, -0.0041, -0.0052, -0.0146]),
#  tensor([-0.0061, -0.0041, -0.0052, -0.0146,  0.0031]),
#  tensor([-0.0041, -0.0052, -0.0146,  0.0031,  0.0476]),
#  tensor([-0.0052, -0.0146,  0.0031,  0.0476,  0.0106]),
#  tensor([-0.0146,  0.0031,  0.0476,  0.0106, -0.0081]),
#  tensor([ 0.0031,  0.0476,  0.0106, -0.0081,  0.0024]),
#  tensor([ 0.0476,  0.0106, -0.0081,  0.0024, -0.0019]),
#  tensor([ 0.0106, -0.0081,  0.0024, -0.0019,  0.0079]),
#  tensor([-0.0081,  0.0024, -0.0019,  0.0079, -0.0111]),
#  tensor([ 0.0024, -0.0019,  0.0079, -0.0111,  0.0097]),
#  tensor([-0.0019,  0.0079, -0.0111,  0.0097,  0.0005]),
#  tensor([ 0.0079, -0.0111,  0.0097,  0.0005,  0.0040]),
#  tensor([-0.0111,  0.0097,  0.0005,  0.0040,  0.0175]),
#  tensor([0.0097, 0.0005, 0.0040, 0.0175, 0.0018]),
#  tensor([0.0005, 0.0040, 0.0175, 0.0018, 0.0023]),
#  tensor([ 0.0040,  0.0175,  0.0018,  0.0023, -0.0113]),
#  tensor([ 0.0175,  0.0018,  0.0023, -0.0113, -0.0074]),
#  tensor([ 0.0018,  0.0023, -0.0113, -0.0074, -0.0077]),
#  tensor([ 0.0023, -0.0113, -0.0074, -0.0077, -0.0183]),
#  tensor([-0.0113, -0.0074, -0.0077, -0.0183,  0.0059]),
#  tensor([-0.0074, -0.0077, -0.0183,  0.0059,  0.0232]),
#  tensor([-0.0077, -0.0183,  0.0059,  0.0232,  0.0135]),
#  tensor([-0.0183,  0.0059,  0.0232,  0.0135,  0.0091]),
#  tensor([0.0059, 0.0232, 0.0135, 0.0091, 0.0008]),
#  tensor([0.0232, 0.0135, 0.0091, 0.0008, 0.0174]),
#  tensor([0.0135, 0.0091, 0.0008, 0.0174, 0.0039]),
#  tensor([ 0.0091,  0.0008,  0.0174,  0.0039, -0.0021]),
#  tensor([ 0.0008,  0.0174,  0.0039, -0.0021, -0.0174]),
#  tensor([ 0.0174,  0.0039, -0.0021, -0.0174,  0.0143]),
#  tensor([ 0.0039, -0.0021, -0.0174,  0.0143, -0.0348]),
#  tensor([-0.0021, -0.0174,  0.0143, -0.0348, -0.0055]),
#  tensor([-0.0174,  0.0143, -0.0348, -0.0055,  0.0169]),
#  tensor([ 0.0143, -0.0348, -0.0055,  0.0169, -0.0081]),
#  tensor([-3.4765e-02, -5.5350e-03,  1.6936e-02, -8.0754e-03, -6.5473e-05]),
#  tensor([-5.5350e-03,  1.6936e-02, -8.0754e-03, -6.5473e-05,  1.0330e-02]),
#  tensor([ 1.6936e-02, -8.0754e-03, -6.5473e-05,  1.0330e-02,  3.1696e-02]),
#  tensor([-8.0754e-03, -6.5473e-05,  1.0330e-02,  3.1696e-02, -3.5565e-04]),
#  tensor([-6.5473e-05,  1.0330e-02,  3.1696e-02, -3.5565e-04,  2.2557e-04]),
#  tensor([ 0.0103,  0.0317, -0.0004,  0.0002, -0.0029]),
#  tensor([ 0.0317, -0.0004,  0.0002, -0.0029,  0.0138]),
#  tensor([-0.0004,  0.0002, -0.0029,  0.0138,  0.0005]),
#  tensor([ 0.0002, -0.0029,  0.0138,  0.0005, -0.0066]),
#  tensor([-0.0029,  0.0138,  0.0005, -0.0066,  0.0021]),
#  tensor([ 0.0138,  0.0005, -0.0066,  0.0021,  0.0067]),
#  tensor([ 0.0005, -0.0066,  0.0021,  0.0067,  0.0109]),
#  tensor([-0.0066,  0.0021,  0.0067,  0.0109, -0.0090]),
#  tensor([ 0.0021,  0.0067,  0.0109, -0.0090,  0.0164]),
#  tensor([ 0.0067,  0.0109, -0.0090,  0.0164, -0.0056]),
#  tensor([ 0.0109, -0.0090,  0.0164, -0.0056, -0.0019]),
#  tensor([-0.0090,  0.0164, -0.0056, -0.0019,  0.0055]),
#  tensor([ 0.0164, -0.0056, -0.0019,  0.0055,  0.0094]),
#  tensor([-0.0056, -0.0019,  0.0055,  0.0094,  0.0210]),
#  tensor([-0.0019,  0.0055,  0.0094,  0.0210, -0.0192]),
#  tensor([ 0.0055,  0.0094,  0.0210, -0.0192,  0.0036]),
#  tensor([ 0.0094,  0.0210, -0.0192,  0.0036, -0.0072]),
#  tensor([ 0.0210, -0.0192,  0.0036, -0.0072,  0.0020]),
#  tensor([-0.0192,  0.0036, -0.0072,  0.0020, -0.0134]),
#  tensor([ 0.0036, -0.0072,  0.0020, -0.0134, -0.0077]),
#  tensor([-0.0072,  0.0020, -0.0134, -0.0077,  0.0151]),
#  tensor([ 0.0020, -0.0134, -0.0077,  0.0151, -0.0105]),
#  tensor([-0.0134, -0.0077,  0.0151, -0.0105, -0.0231]),
#  tensor([-0.0077,  0.0151, -0.0105, -0.0231, -0.0031]),
#  tensor([ 0.0151, -0.0105, -0.0231, -0.0031, -0.0015]),
#  tensor([-0.0105, -0.0231, -0.0031, -0.0015,  0.0267]),
#  tensor([-0.0231, -0.0031, -0.0015,  0.0267, -0.0423]),
#  tensor([-0.0031, -0.0015,  0.0267, -0.0423,  0.0204]),
#  tensor([-0.0015,  0.0267, -0.0423,  0.0204,  0.0073]),
#  tensor([ 0.0267, -0.0423,  0.0204,  0.0073,  0.0129]),
#  tensor([-0.0423,  0.0204,  0.0073,  0.0129, -0.0089]),
#  tensor([ 0.0204,  0.0073,  0.0129, -0.0089, -0.0025]),
#  tensor([ 0.0073,  0.0129, -0.0089, -0.0025,  0.0148]),
#  tensor([ 0.0129, -0.0089, -0.0025,  0.0148, -0.0038]),
#  tensor([-0.0089, -0.0025,  0.0148, -0.0038, -0.0237]),
#  tensor([-0.0025,  0.0148, -0.0038, -0.0237,  0.0093]),
#  tensor([ 0.0148, -0.0038, -0.0237,  0.0093, -0.0175]),
#  tensor([-0.0038, -0.0237,  0.0093, -0.0175,  0.0026]),
#  tensor([-0.0237,  0.0093, -0.0175,  0.0026,  0.0040]),
#  tensor([ 0.0093, -0.0175,  0.0026,  0.0040, -0.0146]),
#  tensor([-0.0175,  0.0026,  0.0040, -0.0146, -0.0171]),
#  tensor([ 0.0026,  0.0040, -0.0146, -0.0171,  0.0344]),
#  tensor([ 0.0040, -0.0146, -0.0171,  0.0344,  0.0057]),
#  tensor([-0.0146, -0.0171,  0.0344,  0.0057,  0.0027]),
#  tensor([-0.0171,  0.0344,  0.0057,  0.0027,  0.0188]),
#  tensor([0.0344, 0.0057, 0.0027, 0.0188, 0.0120]),
#  tensor([ 0.0057,  0.0027,  0.0188,  0.0120, -0.0029]),
#  tensor([ 0.0027,  0.0188,  0.0120, -0.0029, -0.0077]),
#  tensor([ 0.0188,  0.0120, -0.0029, -0.0077,  0.0093]),
#  tensor([ 0.0120, -0.0029, -0.0077,  0.0093, -0.0015]),
#  tensor([-0.0029, -0.0077,  0.0093, -0.0015, -0.0085]),
#  tensor([-0.0077,  0.0093, -0.0015, -0.0085,  0.0223]),
#  tensor([ 0.0093, -0.0015, -0.0085,  0.0223,  0.0040]),
#  tensor([-0.0015, -0.0085,  0.0223,  0.0040,  0.0162]),
#  tensor([-0.0085,  0.0223,  0.0040,  0.0162, -0.0116]),
#  tensor([ 0.0223,  0.0040,  0.0162, -0.0116, -0.0117]),
#  tensor([ 0.0040,  0.0162, -0.0116, -0.0117, -0.0107]),
#  tensor([ 0.0162, -0.0116, -0.0117, -0.0107,  0.0091]),
#  tensor([-0.0116, -0.0117, -0.0107,  0.0091,  0.0154]),
#  tensor([-0.0117, -0.0107,  0.0091,  0.0154,  0.0107]),
#  tensor([-0.0107,  0.0091,  0.0154,  0.0107, -0.0061]),
#  tensor([ 0.0091,  0.0154,  0.0107, -0.0061, -0.0042]),
#  tensor([ 0.0154,  0.0107, -0.0061, -0.0042,  0.0102]),
#  tensor([ 0.0107, -0.0061, -0.0042,  0.0102,  0.0064]),
#  tensor([-0.0061, -0.0042,  0.0102,  0.0064, -0.0133]),
#  tensor([-0.0042,  0.0102,  0.0064, -0.0133,  0.0078]),
#  tensor([ 0.0102,  0.0064, -0.0133,  0.0078, -0.0034]),
#  tensor([ 0.0064, -0.0133,  0.0078, -0.0034, -0.0012]),
#  tensor([-0.0133,  0.0078, -0.0034, -0.0012,  0.0117]),
#  tensor([ 0.0078, -0.0034, -0.0012,  0.0117, -0.0021]),
#  tensor([-0.0034, -0.0012,  0.0117, -0.0021, -0.0002]),
#  tensor([-0.0012,  0.0117, -0.0021, -0.0002, -0.0135]),
#  tensor([ 0.0117, -0.0021, -0.0002, -0.0135,  0.0068]),
#  tensor([-0.0021, -0.0002, -0.0135,  0.0068, -0.0106]),
#  tensor([-0.0002, -0.0135,  0.0068, -0.0106,  0.0036]),
#  tensor([-0.0135,  0.0068, -0.0106,  0.0036,  0.0152]),
#  tensor([ 0.0068, -0.0106,  0.0036,  0.0152,  0.0247]),
#  tensor([-0.0106,  0.0036,  0.0152,  0.0247,  0.0057]),
#  tensor([0.0036, 0.0152, 0.0247, 0.0057, 0.0112]),
#  tensor([ 0.0152,  0.0247,  0.0057,  0.0112, -0.0021]),
#  tensor([ 0.0247,  0.0057,  0.0112, -0.0021,  0.0034]),
#  tensor([ 0.0057,  0.0112, -0.0021,  0.0034, -0.0171]),
#  tensor([ 0.0112, -0.0021,  0.0034, -0.0171, -0.0258]),
#  tensor([-0.0021,  0.0034, -0.0171, -0.0258, -0.0039]),
#  tensor([ 0.0034, -0.0171, -0.0258, -0.0039, -0.0395]),
#  tensor([-0.0171, -0.0258, -0.0039, -0.0395,  0.0146]),
#  tensor([-0.0258, -0.0039, -0.0395,  0.0146, -0.0021]),
#  tensor([-0.0039, -0.0395,  0.0146, -0.0021,  0.0299]),
#  tensor([-0.0395,  0.0146, -0.0021,  0.0299, -0.0146]),
#  tensor([ 0.0146, -0.0021,  0.0299, -0.0146, -0.0188]),
#  tensor([-0.0021,  0.0299, -0.0146, -0.0188,  0.0182]),
#  tensor([ 0.0299, -0.0146, -0.0188,  0.0182, -0.0295]),
#  tensor([-0.0146, -0.0188,  0.0182, -0.0295,  0.0009]),
#  tensor([-0.0188,  0.0182, -0.0295,  0.0009,  0.0181]),
#  tensor([ 0.0182, -0.0295,  0.0009,  0.0181,  0.0209]),
#  tensor([-0.0295,  0.0009,  0.0181,  0.0209, -0.0165]),
#  tensor([ 0.0009,  0.0181,  0.0209, -0.0165,  0.0088]),
#  tensor([ 0.0181,  0.0209, -0.0165,  0.0088,  0.0037]),
#  tensor([ 0.0209, -0.0165,  0.0088,  0.0037, -0.0328]),
#  tensor([-0.0165,  0.0088,  0.0037, -0.0328,  0.0099]),
#  tensor([ 0.0088,  0.0037, -0.0328,  0.0099,  0.0039]),
#  tensor([ 0.0037, -0.0328,  0.0099,  0.0039,  0.0064]),
#  tensor([-0.0328,  0.0099,  0.0039,  0.0064,  0.0205]),
#  tensor([0.0099, 0.0039, 0.0064, 0.0205, 0.0057]),
#  tensor([ 0.0039,  0.0064,  0.0205,  0.0057, -0.0079]),
#  tensor([ 0.0064,  0.0205,  0.0057, -0.0079,  0.0112]),
#  tensor([ 0.0205,  0.0057, -0.0079,  0.0112,  0.0366]),
#  tensor([ 0.0057, -0.0079,  0.0112,  0.0366,  0.0049]),
#  tensor([-0.0079,  0.0112,  0.0366,  0.0049,  0.0181]),
#  tensor([0.0112, 0.0366, 0.0049, 0.0181, 0.0011]),
#  tensor([0.0366, 0.0049, 0.0181, 0.0011, 0.0190]),
#  tensor([ 0.0049,  0.0181,  0.0011,  0.0190, -0.0101]),
#  tensor([ 0.0181,  0.0011,  0.0190, -0.0101,  0.0069]),
#  tensor([ 0.0011,  0.0190, -0.0101,  0.0069, -0.0176]),
#  tensor([ 0.0190, -0.0101,  0.0069, -0.0176,  0.0093]),
#  tensor([-0.0101,  0.0069, -0.0176,  0.0093, -0.0071]),
#  tensor([ 0.0069, -0.0176,  0.0093, -0.0071, -0.0095]),
#  tensor([-0.0176,  0.0093, -0.0071, -0.0095, -0.0144]),
#  tensor([ 0.0093, -0.0071, -0.0095, -0.0144,  0.0043]),
#  tensor([-0.0071, -0.0095, -0.0144,  0.0043, -0.0050]),
#  tensor([-0.0095, -0.0144,  0.0043, -0.0050,  0.0004]),
#  tensor([-0.0144,  0.0043, -0.0050,  0.0004, -0.0201]),
#  tensor([ 0.0043, -0.0050,  0.0004, -0.0201,  0.0089]),
#  tensor([-0.0050,  0.0004, -0.0201,  0.0089,  0.0107]),
#  tensor([ 0.0004, -0.0201,  0.0089,  0.0107, -0.0249]),
#  tensor([-0.0201,  0.0089,  0.0107, -0.0249, -0.0212]),
#  tensor([ 0.0089,  0.0107, -0.0249, -0.0212,  0.0044]),
#  tensor([ 0.0107, -0.0249, -0.0212,  0.0044,  0.0132]),
#  tensor([-0.0249, -0.0212,  0.0044,  0.0132, -0.0095]),
#  tensor([-0.0212,  0.0044,  0.0132, -0.0095, -0.0200]),
#  tensor([ 0.0044,  0.0132, -0.0095, -0.0200,  0.0029]),
#  tensor([ 0.0132, -0.0095, -0.0200,  0.0029,  0.0041]),
#  tensor([-0.0095, -0.0200,  0.0029,  0.0041,  0.0223]),
#  tensor([-0.0200,  0.0029,  0.0041,  0.0223,  0.0096]),
#  tensor([ 0.0029,  0.0041,  0.0223,  0.0096, -0.0029]),
#  tensor([ 0.0041,  0.0223,  0.0096, -0.0029, -0.0074]),
#  tensor([ 0.0223,  0.0096, -0.0029, -0.0074, -0.0077]),
#  tensor([ 0.0096, -0.0029, -0.0074, -0.0077,  0.0139]),
#  tensor([-0.0029, -0.0074, -0.0077,  0.0139, -0.0248]),
#  tensor([-0.0074, -0.0077,  0.0139, -0.0248,  0.0017]),
#  tensor([-0.0077,  0.0139, -0.0248,  0.0017,  0.0458]),
#  tensor([ 0.0139, -0.0248,  0.0017,  0.0458,  0.0031]),
#  tensor([-0.0248,  0.0017,  0.0458,  0.0031,  0.0296]),
#  tensor([0.0017, 0.0458, 0.0031, 0.0296, 0.0058]),
#  tensor([ 0.0458,  0.0031,  0.0296,  0.0058, -0.0017]),
#  tensor([ 0.0031,  0.0296,  0.0058, -0.0017, -0.0151]),
#  tensor([ 0.0296,  0.0058, -0.0017, -0.0151,  0.0101]),
#  tensor([ 0.0058, -0.0017, -0.0151,  0.0101,  0.0133]),
#  tensor([-0.0017, -0.0151,  0.0101,  0.0133,  0.0050]),
#  tensor([-0.0151,  0.0101,  0.0133,  0.0050,  0.0078]),
#  tensor([0.0101, 0.0133, 0.0050, 0.0078, 0.0026]),
#  tensor([ 0.0133,  0.0050,  0.0078,  0.0026, -0.0067]),
#  tensor([ 0.0050,  0.0078,  0.0026, -0.0067,  0.0067]),
#  tensor([ 0.0078,  0.0026, -0.0067,  0.0067, -0.0053]),
#  tensor([ 0.0026, -0.0067,  0.0067, -0.0053,  0.0026]),
#  tensor([-0.0067,  0.0067, -0.0053,  0.0026,  0.0045]),
#  tensor([ 0.0067, -0.0053,  0.0026,  0.0045, -0.0009]),
#  tensor([-0.0053,  0.0026,  0.0045, -0.0009,  0.0050]),
#  tensor([ 0.0026,  0.0045, -0.0009,  0.0050, -0.0086]),
#  tensor([ 0.0045, -0.0009,  0.0050, -0.0086, -0.0075]),
#  tensor([-0.0009,  0.0050, -0.0086, -0.0075,  0.0082]),
#  tensor([ 0.0050, -0.0086, -0.0075,  0.0082,  0.0128]),
#  tensor([-0.0086, -0.0075,  0.0082,  0.0128,  0.0020]),
#  tensor([-0.0075,  0.0082,  0.0128,  0.0020,  0.0071]),
#  tensor([ 0.0082,  0.0128,  0.0020,  0.0071, -0.0013]),
#  tensor([ 0.0128,  0.0020,  0.0071, -0.0013, -0.0106]),
#  tensor([ 0.0020,  0.0071, -0.0013, -0.0106, -0.0121]),
#  tensor([ 0.0071, -0.0013, -0.0106, -0.0121,  0.0077]),
#  tensor([-0.0013, -0.0106, -0.0121,  0.0077,  0.0105]),
#  tensor([-0.0106, -0.0121,  0.0077,  0.0105,  0.0073]),
#  tensor([-0.0121,  0.0077,  0.0105,  0.0073,  0.0048]),
#  tensor([ 0.0077,  0.0105,  0.0073,  0.0048, -0.0173]),
#  tensor([ 0.0105,  0.0073,  0.0048, -0.0173,  0.0103]),
#  tensor([ 0.0073,  0.0048, -0.0173,  0.0103,  0.0140]),
#  tensor([ 0.0048, -0.0173,  0.0103,  0.0140, -0.0110]),
#  tensor([-0.0173,  0.0103,  0.0140, -0.0110,  0.0001]),
#  tensor([ 0.0103,  0.0140, -0.0110,  0.0001, -0.0018]),
#  tensor([ 0.0140, -0.0110,  0.0001, -0.0018, -0.0051]),
#  tensor([-0.0110,  0.0001, -0.0018, -0.0051,  0.0009]),
#  tensor([ 0.0001, -0.0018, -0.0051,  0.0009,  0.0001]),
#  tensor([-0.0018, -0.0051,  0.0009,  0.0001, -0.0076]),
#  tensor([-0.0051,  0.0009,  0.0001, -0.0076,  0.0047]),
#  tensor([ 0.0009,  0.0001, -0.0076,  0.0047,  0.0054]),
#  tensor([ 0.0001, -0.0076,  0.0047,  0.0054, -0.0004]),
#  tensor([-0.0076,  0.0047,  0.0054, -0.0004, -0.0083]),
#  tensor([ 0.0047,  0.0054, -0.0004, -0.0083,  0.0002]),
#  ...]

# %%
combined_df
# Out:
#         PERMNO   DlyCalDt  ExcessReturn
# 0        10138 2000-01-03     -0.049215
# 1        10138 2000-01-04     -0.030396
# 2        10138 2000-01-05     -0.001983
# 3        10138 2000-01-06      0.029266
# 4        10138 2000-01-07     -0.007289
# ...        ...        ...           ...
# 311945   92655 2024-12-24     -0.000587
# 311946   92655 2024-12-26      0.009863
# 311947   92655 2024-12-27     -0.002380
# 311948   92655 2024-12-30     -0.004409
# 311949   92655 2024-12-31     -0.003932
#
# [311950 rows x 3 columns]

# %%
print(len(contexts))
# Out:
# 112400

# %%
y_test = pd.Series(targets)

results = pd.DataFrame(records)

# %%
# Creating a Function to Calculate Predictive-R2 Used in the Finance Literature
def r2(y_true, y_pred):
    return 1-(((y_true-y_pred)**2).sum()/(y_true**2).sum())

# %%
# Zero Shot Chronos-Bolt-Tiny
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-bolt-tiny',
    device_map=device_map,
    torch_dtype=torch.float32
)

quantiles, means = pipeline.predict_quantiles(context=contexts, prediction_length=1, quantile_levels=[0.5])
preds = [m.cpu().squeeze().item() for m in means]
y_chr_bolt_tiny = pd.Series(preds)

results['y_chr_bolt_tiny'] = y_chr_bolt_tiny
r2_chr_bolt_tiny  = r2(y_test, y_chr_bolt_tiny)
mse_chr_bolt_tiny = mean_squared_error(y_test, y_chr_bolt_tiny)
mae_chr_bolt_tiny = mean_absolute_error(y_test, y_chr_bolt_tiny)
da_chr_bolt_tiny = (np.sign(y_test) == np.sign(y_chr_bolt_tiny)).mean()
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.

# %%
# Zero Shot Chronos-Bolt-Mini
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-bolt-mini',
    device_map=device_map,
    torch_dtype=torch.float32
)

quantiles, means = pipeline.predict_quantiles(context=contexts, prediction_length=1, quantile_levels=[0.5])
preds = [m.cpu().squeeze().item() for m in means]
y_chr_bolt_mini = pd.Series(preds)

results['y_chr_bolt_mini'] = y_chr_bolt_mini
r2_chr_bolt_mini  = r2(y_test, y_chr_bolt_mini)
mse_chr_bolt_mini = mean_squared_error(y_test, y_chr_bolt_mini)
mae_chr_bolt_mini = mean_absolute_error(y_test, y_chr_bolt_mini)
da_chr_bolt_mini = (np.sign(y_test) == np.sign(y_chr_bolt_mini)).mean()

# %%
# Zero Shot Chronos-Bolt-Small
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-bolt-small',
    device_map=device_map,
    torch_dtype=torch.float32
)

preds = []
for ctx in contexts:
    quantiles, mean = pipeline.predict_quantiles(context=[ctx.to(device)], prediction_length=1, quantile_levels=[0.5])
    preds.append(mean.cpu().squeeze().item())
y_chr_bolt_small = pd.Series(preds)

results['y_chr_bolt_small'] = y_chr_bolt_small
r2_chr_bolt_small  = r2(y_test, y_chr_bolt_small)
mse_chr_bolt_small = mean_squared_error(y_test, y_chr_bolt_small)
mae_chr_bolt_small = mean_absolute_error(y_test, y_chr_bolt_small)
da_chr_bolt_small = (np.sign(y_test) == np.sign(y_chr_bolt_small)).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 10
#       8 preds = []
#       9 for ctx in contexts:
# ---> 10     quantiles, mean = pipeline.predict_quantiles(context=[ctx.to(device)], prediction_length=1, quantile_levels=[0.5])
#      11     preds.append(mean.cpu().squeeze().item())
#      12 y_chr_bolt_small = pd.Series(preds)
#
# File ~\chronos-forecasting\src\chronos\chronos_bolt.py:577, in ChronosBoltPipeline.predict_quantiles(self, context, prediction_length, quantile_levels, **predict_kwargs)
#     572 """
#     573 Refer to the base method (``BaseChronosPipeline.predict_quantiles``).
#     574 """
#     575 # shape (batch_size, prediction_length, len(training_quantile_levels))
#     576 predictions = (
# --> 577     self.predict(context, prediction_length=prediction_length, **predict_kwargs)
#     578     .detach()
#     579     .swapaxes(1, 2)
#     580 )
#     582 training_quantile_levels = self.quantiles
#     584 if set(quantile_levels).issubset(set(training_quantile_levels)):
#     585     # no need to perform intra/extrapolation
#
# File ~\chronos-forecasting\src\chronos\chronos_bolt.py:546, in ChronosBoltPipeline.predict(self, context, prediction_length, limit_prediction_length)
#     544 while remaining > 0:
#     545     with torch.no_grad():
# --> 546         prediction = self.model(
#     547             context=context_tensor,
#     548         ).quantile_preds.to(context_tensor)
#     550     predictions.append(prediction)
#     551     remaining -= prediction.shape[-1]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\chronos-forecasting\src\chronos\chronos_bolt.py:313, in ChronosBoltModelForForecasting.forward(self, context, mask, target, target_mask)
#     304 def forward(
#     305     self,
#     306     context: torch.Tensor,
#    (...)    309     target_mask: Optional[torch.Tensor] = None,
#     310 ) -> ChronosBoltOutput:
#     311     batch_size = context.size(0)
# --> 313     hidden_states, loc_scale, input_embeds, attention_mask = self.encode(
#     314         context=context, mask=mask
#     315     )
#     316     sequence_output = self.decode(input_embeds, attention_mask, hidden_states)
#     318     quantile_preds_shape = (
#     319         batch_size,
#     320         self.num_quantiles,
#     321         self.chronos_config.prediction_length,
#     322     )
#
# File ~\chronos-forecasting\src\chronos\chronos_bolt.py:297, in ChronosBoltModelForForecasting.encode(self, context, mask)
#     288     input_embeds = torch.cat([input_embeds, reg_embeds], dim=-2)
#     289     attention_mask = torch.cat(
#     290         [
#     291             attention_mask.to(self.dtype),
#    (...)    294         dim=-1,
#     295     )
# --> 297 encoder_outputs = self.encoder(
#     298     attention_mask=attention_mask,
#     299     inputs_embeds=input_embeds,
#     300 )
#     302 return encoder_outputs[0], loc_scale, input_embeds, attention_mask
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\models\t5\modeling_t5.py:1131, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1114     layer_outputs = self._gradient_checkpointing_func(
#    1115         layer_module.forward,
#    1116         hidden_states,
#    (...)   1128         cache_position,
#    1129     )
#    1130 else:
# -> 1131     layer_outputs = layer_module(
#    1132         hidden_states,
#    1133         attention_mask=causal_mask,
#    1134         position_bias=position_bias,
#    1135         encoder_hidden_states=encoder_hidden_states,
#    1136         encoder_attention_mask=encoder_extended_attention_mask,
#    1137         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1138         layer_head_mask=layer_head_mask,
#    1139         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1140         past_key_value=past_key_values,
#    1141         use_cache=use_cache,
#    1142         output_attentions=output_attentions,
#    1143         return_dict=return_dict,
#    1144         cache_position=cache_position,
#    1145     )
#    1147 # layer_outputs is a tuple with:
#    1148 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1149 if use_cache is False:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\models\t5\modeling_t5.py:682, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     666 def forward(
#     667     self,
#     668     hidden_states,
#    (...)    680     cache_position=None,
#     681 ):
# --> 682     self_attention_outputs = self.layer[0](
#     683         hidden_states,
#     684         attention_mask=attention_mask,
#     685         position_bias=position_bias,
#     686         layer_head_mask=layer_head_mask,
#     687         past_key_value=past_key_value,
#     688         use_cache=use_cache,
#     689         output_attentions=output_attentions,
#     690         cache_position=cache_position,
#     691     )
#     692     hidden_states, past_key_value = self_attention_outputs[:2]
#     693     attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\models\t5\modeling_t5.py:600, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions, cache_position)
#     588 def forward(
#     589     self,
#     590     hidden_states,
#    (...)    597     cache_position=None,
#     598 ):
#     599     normed_hidden_states = self.layer_norm(hidden_states)
# --> 600     attention_output = self.SelfAttention(
#     601         normed_hidden_states,
#     602         mask=attention_mask,
#     603         position_bias=position_bias,
#     604         layer_head_mask=layer_head_mask,
#     605         past_key_value=past_key_value,
#     606         use_cache=use_cache,
#     607         output_attentions=output_attentions,
#     608         cache_position=cache_position,
#     609     )
#     610     hidden_states = hidden_states + self.dropout(attention_output[0])
#     611     outputs = (hidden_states,) + attention_output[1:]  # add attentions if we output them
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\models\t5\modeling_t5.py:494, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions, cache_position)
#     491 # if key_value_states are provided this layer is used as a cross-attention layer for the decoder
#     492 is_cross_attention = key_value_states is not None
# --> 494 query_states = self.q(hidden_states)
#     495 query_states = query_states.view(batch_size, -1, self.n_heads, self.key_value_proj_dim).transpose(1, 2)
#     497 if past_key_value is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Zero Shot Chronos-Bolt-Base
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-bolt-base',
    device_map=device_map,
    torch_dtype=torch.float32
)

preds = []
for ctx in contexts:
    quantiles, mean = pipeline.predict_quantiles(context=[ctx.to(device)], prediction_length=1, quantile_levels=[0.5])
    preds.append(mean.cpu().squeeze().item())
y_chr_bolt_base = pd.Series(preds)

results['y_chr_bolt_base'] = y_chr_bolt_base
r2_chr_bolt_base  = r2(y_test, y_chr_bolt_base)
mse_chr_bolt_base = mean_squared_error(y_test, y_chr_bolt_base)
mae_chr_bolt_base = mean_absolute_error(y_test, y_chr_bolt_base)
da_chr_bolt_base = (np.sign(y_test) == np.sign(y_chr_bolt_base)).mean()
# Out:
# C:\Users\amaan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\amaan\.cache\huggingface\hub\models--amazon--chronos-bolt-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
# Switching to using CPU for T5 models
device_map = "cpu"
device = torch.device("cpu")

# %%
# Create rolling window for predictors for T5 models
contexts = []
targets = []

for id, grp in combined_df.groupby(ID_COL):
    values = grp[TARGET_COL].values
    dates = grp[DATE_COL].values

    for i in range(len(values) - WINDOW):
        pred_date = dates[i + WINDOW]
        if pred_date >= pd.to_datetime("2016-01-01"):
            contexts.append(torch.tensor(values[i:i+WINDOW], dtype=torch.float32, device=device))
            targets.append(values[i+WINDOW])

# %%
# Zero Shot Chronos-T5-Tiny
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-t5-tiny',
    device_map=device_map,
    torch_dtype=torch.float32
)

preds = []
for ctx in contexts:
    quantiles, mean = pipeline.predict_quantiles(context=[ctx], prediction_length=1, quantile_levels=[0.5])
    preds.append(mean.squeeze().item())
y_chr_t5_tiny = pd.Series(preds)

results['y_chr_t5_tiny'] = y_chr_t5_tiny
r2_chr_t5_tiny  = r2(y_test, y_chr_t5_tiny)
mse_chr_t5_tiny = mean_squared_error(y_test, y_chr_t5_tiny)
mae_chr_t5_tiny = mean_absolute_error(y_test, y_chr_t5_tiny)
da_chr_t5_tiny = (np.sign(y_test) == np.sign(y_chr_t5_tiny)).mean()

# %%
# Zero Shot Chronos-T5-Mini
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-t5-mini',
    device_map=device_map,
    torch_dtype=torch.float32
)

preds = []
for ctx in contexts:
    quantiles, mean = pipeline.predict_quantiles(context=[ctx], prediction_length=1, quantile_levels=[0.5])
    preds.append(mean.squeeze().item())
y_chr_t5_mini = pd.Series(preds)

results['y_chr_t5_mini'] = y_chr_t5_mini
r2_chr_t5_mini  = r2(y_test, y_chr_t5_mini)
mse_chr_t5_mini = mean_squared_error(y_test, y_chr_t5_mini)
mae_chr_t5_mini = mean_absolute_error(y_test, y_chr_t5_mini)
da_chr_t5_mini = (np.sign(y_test) == np.sign(y_chr_t5_mini)).mean()

# %%
# Zero Shot Chronos-T5-Small
pipeline = BaseChronosPipeline.from_pretrained(
    'amazon/chronos-t5-small',
    device_map=device_map,
    torch_dtype=torch.float32
)

preds = []
for ctx in contexts:
    quantiles, mean = pipeline.predict_quantiles(context=[ctx], prediction_length=1, quantile_levels=[0.5])
    preds.append(mean.squeeze().item())
y_chr_t5_small = pd.Series(preds)

results['y_chr_t5_small'] = y_chr_t5_small
r2_chr_t5_small  = r2(y_test, y_chr_t5_small)
mse_chr_t5_small = mean_squared_error(y_test, y_chr_t5_small)
mae_chr_t5_small = mean_absolute_error(y_test, y_chr_t5_small)
da_chr_t5_small = (np.sign(y_test) == np.sign(y_chr_t5_small)).mean()

# %%
# Collating Results

results_matrix = [{
        "Model": "Chronos-Bolt-Tiny",
        "R-squared": r2_chr_bolt_tiny,
        "MSE": mse_chr_bolt_tiny,
        "MAE": mae_chr_bolt_tiny,
        "Direction Accuracy": da_chr_bolt_tiny
    },
    {
        "Model": "Chronos-Bolt-Mini",
        "R-squared": r2_chr_bolt_mini,
        "MSE": mse_chr_bolt_mini,
        "MAE": mae_chr_bolt_mini,
        "Direction Accuracy": da_chr_bolt_mini
    },
    {
        "Model": "Chronos-Bolt-Small",
        "R-squared": r2_chr_bolt_small,
        "MSE": mse_chr_bolt_small,
        "MAE": mae_chr_bolt_small,
        "Direction Accuracy": da_chr_bolt_small
    },
    {
        "Model": "Chronos-Bolt-Base",
        "R-squared": r2_chr_bolt_base,
        "MSE": mse_chr_bolt_base,
        "MAE": mae_chr_bolt_base,
        "Direction Accuracy": da_chr_bolt_base
    },
    {
        "Model": "Chronos-T5-Tiny",
        "R-squared": r2_chr_t5_tiny,
        "MSE": mse_chr_t5_tiny,
        "MAE": mae_chr_t5_tiny,
        "Direction Accuracy": da_chr_t5_tiny
    },
    {
        "Model": "Chronos-T5-Mini",
        "R-squared": r2_chr_t5_mini,
        "MSE": mse_chr_t5_mini,
        "MAE": mae_chr_t5_mini,
        "Direction Accuracy": da_chr_t5_mini
    },
    {
        "Model": "Chronos-T5-Small",
        "R-squared": r2_chr_t5_small,
        "MSE": mse_chr_t5_small,
        "MAE": mae_chr_t5_small,
        "Direction Accuracy": da_chr_t5_small
    }]

results_matrix_df = pd.DataFrame(results_matrix)
results_matrix_df

# %%
# Save Prediction Results
results.to_csv("chronos_predictions(5-day).csv", index=False)
results_matrix_df.to_csv("chronos_results(5-day).csv", index=False)
